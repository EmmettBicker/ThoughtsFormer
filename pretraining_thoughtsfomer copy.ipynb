# %%
# Out:
# Detected 12 layers in the custom model
# MATCH (Explicit) transformer.transformer.layers.0.self_attn.out_proj.weight transformer.h.0.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.0.self_attn.out_proj.bias transformer.h.0.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.1.self_attn.out_proj.weight transformer.h.1.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.1.self_attn.out_proj.bias transformer.h.1.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.2.self_attn.out_proj.weight transformer.h.2.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.2.self_attn.out_proj.bias transformer.h.2.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.3.self_attn.out_proj.weight transformer.h.3.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.3.self_attn.out_proj.bias transformer.h.3.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.4.self_attn.out_proj.weight transformer.h.4.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.4.self_attn.out_proj.bias transformer.h.4.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.5.self_attn.out_proj.weight transformer.h.5.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.5.self_attn.out_proj.bias transformer.h.5.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.6.self_attn.out_proj.weight transformer.h.6.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.6.self_attn.out_proj.bias transformer.h.6.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.7.self_attn.out_proj.weight transformer.h.7.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.7.self_attn.out_proj.bias transformer.h.7.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.8.self_attn.out_proj.weight transformer.h.8.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.8.self_attn.out_proj.bias transformer.h.8.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.9.self_attn.out_proj.weight transformer.h.9.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.9.self_attn.out_proj.bias transformer.h.9.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.10.self_attn.out_proj.weight transformer.h.10.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.10.self_attn.out_proj.bias transformer.h.10.attn.c_proj.bias
# MATCH (Explicit) transformer.transformer.layers.11.self_attn.out_proj.weight transformer.h.11.attn.c_proj.weight
# MATCH (Explicit) transformer.transformer.layers.11.self_attn.out_proj.bias transformer.h.11.attn.c_proj.bias
# MATCH transformer.dual_positional_encoding.learned_positional_encoding.weight : transformer.wpe.weight
# No mapping found for transformer.dual_positional_encoding.position_in_thought_encoding.weight, keeping original
# MATCH (Attention) transformer.transformer.layers.0.self_attn.in_proj_weight transformer.h.0.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.0.self_attn.in_proj_bias transformer.h.0.attn.c_attn
# Shape mismatch for transformer.transformer.layers.0.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.0.linear1.weight transformer.h.0.mlp.c_fc.weight
# MATCH transformer.transformer.layers.0.linear1.bias transformer.h.0.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.0.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.0.linear2.weight transformer.h.0.mlp.c_proj.weight
# MATCH transformer.transformer.layers.0.linear2.bias transformer.h.0.mlp.c_proj.bias
# MATCH transformer.transformer.layers.0.norm1.weight transformer.h.0.ln_1.weight
# MATCH transformer.transformer.layers.0.norm1.bias transformer.h.0.ln_1.bias
# MATCH transformer.transformer.layers.0.norm2.weight transformer.h.0.ln_2.weight
# MATCH transformer.transformer.layers.0.norm2.bias transformer.h.0.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.1.self_attn.in_proj_weight transformer.h.1.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.1.self_attn.in_proj_bias transformer.h.1.attn.c_attn
# Shape mismatch for transformer.transformer.layers.1.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.1.linear1.weight transformer.h.1.mlp.c_fc.weight
# MATCH transformer.transformer.layers.1.linear1.bias transformer.h.1.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.1.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.1.linear2.weight transformer.h.1.mlp.c_proj.weight
# MATCH transformer.transformer.layers.1.linear2.bias transformer.h.1.mlp.c_proj.bias
# MATCH transformer.transformer.layers.1.norm1.weight transformer.h.1.ln_1.weight
# MATCH transformer.transformer.layers.1.norm1.bias transformer.h.1.ln_1.bias
# MATCH transformer.transformer.layers.1.norm2.weight transformer.h.1.ln_2.weight
# MATCH transformer.transformer.layers.1.norm2.bias transformer.h.1.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.2.self_attn.in_proj_weight transformer.h.2.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.2.self_attn.in_proj_bias transformer.h.2.attn.c_attn
# Shape mismatch for transformer.transformer.layers.2.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.2.linear1.weight transformer.h.2.mlp.c_fc.weight
# MATCH transformer.transformer.layers.2.linear1.bias transformer.h.2.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.2.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.2.linear2.weight transformer.h.2.mlp.c_proj.weight
# MATCH transformer.transformer.layers.2.linear2.bias transformer.h.2.mlp.c_proj.bias
# MATCH transformer.transformer.layers.2.norm1.weight transformer.h.2.ln_1.weight
# MATCH transformer.transformer.layers.2.norm1.bias transformer.h.2.ln_1.bias
# MATCH transformer.transformer.layers.2.norm2.weight transformer.h.2.ln_2.weight
# MATCH transformer.transformer.layers.2.norm2.bias transformer.h.2.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.3.self_attn.in_proj_weight transformer.h.3.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.3.self_attn.in_proj_bias transformer.h.3.attn.c_attn
# Shape mismatch for transformer.transformer.layers.3.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.3.linear1.weight transformer.h.3.mlp.c_fc.weight
# MATCH transformer.transformer.layers.3.linear1.bias transformer.h.3.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.3.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.3.linear2.weight transformer.h.3.mlp.c_proj.weight
# MATCH transformer.transformer.layers.3.linear2.bias transformer.h.3.mlp.c_proj.bias
# MATCH transformer.transformer.layers.3.norm1.weight transformer.h.3.ln_1.weight
# MATCH transformer.transformer.layers.3.norm1.bias transformer.h.3.ln_1.bias
# MATCH transformer.transformer.layers.3.norm2.weight transformer.h.3.ln_2.weight
# MATCH transformer.transformer.layers.3.norm2.bias transformer.h.3.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.4.self_attn.in_proj_weight transformer.h.4.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.4.self_attn.in_proj_bias transformer.h.4.attn.c_attn
# Shape mismatch for transformer.transformer.layers.4.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.4.linear1.weight transformer.h.4.mlp.c_fc.weight
# MATCH transformer.transformer.layers.4.linear1.bias transformer.h.4.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.4.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.4.linear2.weight transformer.h.4.mlp.c_proj.weight
# MATCH transformer.transformer.layers.4.linear2.bias transformer.h.4.mlp.c_proj.bias
# MATCH transformer.transformer.layers.4.norm1.weight transformer.h.4.ln_1.weight
# MATCH transformer.transformer.layers.4.norm1.bias transformer.h.4.ln_1.bias
# MATCH transformer.transformer.layers.4.norm2.weight transformer.h.4.ln_2.weight
# MATCH transformer.transformer.layers.4.norm2.bias transformer.h.4.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.5.self_attn.in_proj_weight transformer.h.5.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.5.self_attn.in_proj_bias transformer.h.5.attn.c_attn
# Shape mismatch for transformer.transformer.layers.5.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.5.linear1.weight transformer.h.5.mlp.c_fc.weight
# MATCH transformer.transformer.layers.5.linear1.bias transformer.h.5.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.5.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.5.linear2.weight transformer.h.5.mlp.c_proj.weight
# MATCH transformer.transformer.layers.5.linear2.bias transformer.h.5.mlp.c_proj.bias
# MATCH transformer.transformer.layers.5.norm1.weight transformer.h.5.ln_1.weight
# MATCH transformer.transformer.layers.5.norm1.bias transformer.h.5.ln_1.bias
# MATCH transformer.transformer.layers.5.norm2.weight transformer.h.5.ln_2.weight
# MATCH transformer.transformer.layers.5.norm2.bias transformer.h.5.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.6.self_attn.in_proj_weight transformer.h.6.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.6.self_attn.in_proj_bias transformer.h.6.attn.c_attn
# Shape mismatch for transformer.transformer.layers.6.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.6.linear1.weight transformer.h.6.mlp.c_fc.weight
# MATCH transformer.transformer.layers.6.linear1.bias transformer.h.6.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.6.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.6.linear2.weight transformer.h.6.mlp.c_proj.weight
# MATCH transformer.transformer.layers.6.linear2.bias transformer.h.6.mlp.c_proj.bias
# MATCH transformer.transformer.layers.6.norm1.weight transformer.h.6.ln_1.weight
# MATCH transformer.transformer.layers.6.norm1.bias transformer.h.6.ln_1.bias
# MATCH transformer.transformer.layers.6.norm2.weight transformer.h.6.ln_2.weight
# MATCH transformer.transformer.layers.6.norm2.bias transformer.h.6.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.7.self_attn.in_proj_weight transformer.h.7.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.7.self_attn.in_proj_bias transformer.h.7.attn.c_attn
# Shape mismatch for transformer.transformer.layers.7.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.7.linear1.weight transformer.h.7.mlp.c_fc.weight
# MATCH transformer.transformer.layers.7.linear1.bias transformer.h.7.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.7.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.7.linear2.weight transformer.h.7.mlp.c_proj.weight
# MATCH transformer.transformer.layers.7.linear2.bias transformer.h.7.mlp.c_proj.bias
# MATCH transformer.transformer.layers.7.norm1.weight transformer.h.7.ln_1.weight
# MATCH transformer.transformer.layers.7.norm1.bias transformer.h.7.ln_1.bias
# MATCH transformer.transformer.layers.7.norm2.weight transformer.h.7.ln_2.weight
# MATCH transformer.transformer.layers.7.norm2.bias transformer.h.7.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.8.self_attn.in_proj_weight transformer.h.8.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.8.self_attn.in_proj_bias transformer.h.8.attn.c_attn
# Shape mismatch for transformer.transformer.layers.8.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.8.linear1.weight transformer.h.8.mlp.c_fc.weight
# MATCH transformer.transformer.layers.8.linear1.bias transformer.h.8.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.8.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.8.linear2.weight transformer.h.8.mlp.c_proj.weight
# MATCH transformer.transformer.layers.8.linear2.bias transformer.h.8.mlp.c_proj.bias
# MATCH transformer.transformer.layers.8.norm1.weight transformer.h.8.ln_1.weight
# MATCH transformer.transformer.layers.8.norm1.bias transformer.h.8.ln_1.bias
# MATCH transformer.transformer.layers.8.norm2.weight transformer.h.8.ln_2.weight
# MATCH transformer.transformer.layers.8.norm2.bias transformer.h.8.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.9.self_attn.in_proj_weight transformer.h.9.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.9.self_attn.in_proj_bias transformer.h.9.attn.c_attn
# Shape mismatch for transformer.transformer.layers.9.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.9.linear1.weight transformer.h.9.mlp.c_fc.weight
# MATCH transformer.transformer.layers.9.linear1.bias transformer.h.9.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.9.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.9.linear2.weight transformer.h.9.mlp.c_proj.weight
# MATCH transformer.transformer.layers.9.linear2.bias transformer.h.9.mlp.c_proj.bias
# MATCH transformer.transformer.layers.9.norm1.weight transformer.h.9.ln_1.weight
# MATCH transformer.transformer.layers.9.norm1.bias transformer.h.9.ln_1.bias
# MATCH transformer.transformer.layers.9.norm2.weight transformer.h.9.ln_2.weight
# MATCH transformer.transformer.layers.9.norm2.bias transformer.h.9.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.10.self_attn.in_proj_weight transformer.h.10.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.10.self_attn.in_proj_bias transformer.h.10.attn.c_attn
# Shape mismatch for transformer.transformer.layers.10.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.10.linear1.weight transformer.h.10.mlp.c_fc.weight
# MATCH transformer.transformer.layers.10.linear1.bias transformer.h.10.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.10.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.10.linear2.weight transformer.h.10.mlp.c_proj.weight
# MATCH transformer.transformer.layers.10.linear2.bias transformer.h.10.mlp.c_proj.bias
# MATCH transformer.transformer.layers.10.norm1.weight transformer.h.10.ln_1.weight
# MATCH transformer.transformer.layers.10.norm1.bias transformer.h.10.ln_1.bias
# MATCH transformer.transformer.layers.10.norm2.weight transformer.h.10.ln_2.weight
# MATCH transformer.transformer.layers.10.norm2.bias transformer.h.10.ln_2.bias
# MATCH (Attention) transformer.transformer.layers.11.self_attn.in_proj_weight transformer.h.11.attn.c_attn
# MATCH (Attention) transformer.transformer.layers.11.self_attn.in_proj_bias transformer.h.11.attn.c_attn
# Shape mismatch for transformer.transformer.layers.11.linear1.weight, GPT-2 shape: torch.Size([768, 3072]), Custom shape: torch.Size([3072, 768])
# MATCH (Reshaped) transformer.transformer.layers.11.linear1.weight transformer.h.11.mlp.c_fc.weight
# MATCH transformer.transformer.layers.11.linear1.bias transformer.h.11.mlp.c_fc.bias
# Shape mismatch for transformer.transformer.layers.11.linear2.weight, GPT-2 shape: torch.Size([3072, 768]), Custom shape: torch.Size([768, 3072])
# MATCH (Reshaped) transformer.transformer.layers.11.linear2.weight transformer.h.11.mlp.c_proj.weight
# MATCH transformer.transformer.layers.11.linear2.bias transformer.h.11.mlp.c_proj.bias
# MATCH transformer.transformer.layers.11.norm1.weight transformer.h.11.ln_1.weight
# MATCH transformer.transformer.layers.11.norm1.bias transformer.h.11.ln_1.bias
# MATCH transformer.transformer.layers.11.norm2.weight transformer.h.11.ln_2.weight
# MATCH transformer.transformer.layers.11.norm2.bias transformer.h.11.ln_2.bias
# MATCH transformer.transformer.norm.weight : transformer.ln_f.weight
# MATCH transformer.transformer.norm.bias : transformer.ln_f.bias
# MATCH (head) policy_feedforward.weight : lm_head.weight
# No mapping found for value_feedforward.0.weight, keeping original (custom policy/value layers)
# No mapping found for value_feedforward.0.bias, keeping original (custom policy/value layers)
# No mapping found for value_feedforward.2.weight, keeping original (custom policy/value layers)
# No mapping found for value_feedforward.2.bias, keeping original (custom policy/value layers)
# MATCH token_embedding.weight transformer.wte.weight
# MATCH transformer.transformer.norm.weight transformer.ln_f.weight
# MATCH transformer.transformer.norm.bias transformer.ln_f.bias

# %%
import torch
input = torch.load("test.pt")

from transformers import GPT2LMHeadModel
from one_step_thoughtsformer import ThoughtsFormer
# t = GPT2Tokenizer.from_pretrained("gpt2")
pret = GPT2LMHeadModel.from_pretrained("gpt2")
custom_model = ThoughtsFormer(num_layers=12,vocab_size=50257, d_embed = 768, feed_forward_dim=768 * 4, n_head=12, max_context_length=1024, thought_length=0, dropout=0.15, sinusoidal_position_encoding=False)
pdict = pret.state_dict()
cdict = custom_model.state_dict()
# sentence = "Once upon a time"
pdict = pret.state_dict()
cdict = custom_model.state_dict()

explicit_map = {
    'token_embedding.weight' : 'transformer.wte.weight',
    'policy_feedforward.weight' : 'lm_head.weight',
    'transformer.transformer.norm.weight' : 'transformer.ln_f.weight',
    'transformer.transformer.norm.bias' : 'transformer.ln_f.bias',
    'transformer.dual_positional_encoding.learned_positional_encoding.weight' : 'transformer.wpe.weight'
}

param_counter = 0

for k, v in explicit_map.items():
    param_counter+= 1
    assert cdict[k].shape == pdict[v].shape
    cdict[k].copy_(pdict[v])
    
for i in range(12):
    layer_explicit_map = {
        f"transformer.transformer.layers.{i}.linear1.weight" : f"transformer.h.{i}.mlp.c_fc.weight" ,
        f"transformer.transformer.layers.{i}.linear1.bias" : f"transformer.h.{i}.mlp.c_fc.bias" ,
        f"transformer.transformer.layers.{i}.linear2.weight" : f"transformer.h.{i}.mlp.c_proj.weight", 
        f"transformer.transformer.layers.{i}.linear2.bias" : f"transformer.h.{i}.mlp.c_proj.bias" ,
        f"transformer.transformer.layers.{i}.norm1.weight" : f"transformer.h.{i}.ln_1.weight", 
        f"transformer.transformer.layers.{i}.norm1.bias" : f"transformer.h.{i}.ln_1.bias", 
        f"transformer.transformer.layers.{i}.norm2.weight" : f"transformer.h.{i}.ln_2.weight", 
        f"transformer.transformer.layers.{i}.norm2.bias" : f"transformer.h.{i}.ln_2.bias", 
        f"transformer.transformer.layers.{i}.self_attn.out_proj.weight" : f"transformer.h.{i}.attn.c_proj.weight", 
        f"transformer.transformer.layers.{i}.self_attn.out_proj.bias" : f"transformer.h.{i}.attn.c_proj.bias",
        f"transformer.transformer.layers.{i}.self_attn.in_proj_weight":  f"transformer.h.{i}.attn.c_attn.weight",
        f"transformer.transformer.layers.{i}.self_attn.in_proj_bias" : f"transformer.h.{i}.attn.c_attn.bias"
    }
    
    transposed = ['attn.c_attn.weight', 'attn.c_proj.weight', 'mlp.c_fc.weight', 'mlp.c_proj.weight']
    for k, v in layer_explicit_map.items():
        
        if any(v.endswith(w) for w in transposed):
            assert pdict[v].shape[::-1] == cdict[k].shape
            with torch.no_grad():
                cdict[k].copy_(pdict[v].t())
        else:
            # print(cdict[k].shape, pdict[v].shape, k, v)
            with torch.no_grad():
                assert cdict[k].shape == pdict[v].shape
                cdict[k].copy_(pdict[v])
    
custom_model.load_state_dict(cdict)
# cdict['token_embedding.weight'].shape
# cdict['transformer.transformer.layers.0.linear2.weight'].shape

sentence = "once upon a time"


from bpe import BPETokenizer
tokenizer = BPETokenizer()

torch.manual_seed(42)
with torch.no_grad():
    tokens = torch.tensor(tokenizer(sentence)).view(1,-1)
    custom_model.eval()
    predictions = custom_model.forward_ppo_with_tokens(tokens, torch.zeros_like(tokens),0)[0]
  
    print(custom_model.transformer.transformer.layers[0](input))
    
    
    print(custom_model.transformer.transformer.layers[0](input))

x = predictions.argmax(dim=-1)
tokenizer.decode(x[0])
print("\n\nDesired Output")
print(pret(tokens,output_hidden_states=True).hidden_states[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 input = torch.load("test.pt")
#       3 import torch
#       4 from transformers import GPT2LMHeadModel
#
# NameError: name 'torch' is not defined

# %%
# Desired Output
# tensor([[[ 0.3191,  0.6466,  1.1327,  ..., -0.0743,  0.7379, -0.3372],
#          [-0.3657, -0.3845, -0.2498,  ..., -0.0071,  0.2876,  0.2585],
#          [-1.4182,  0.1991, -0.4063,  ...,  0.0237,  0.1473, -0.4916],
#          [ 0.2380, -0.8441, -0.0074,  ...,  0.6175, -0.6014,  0.4939]]],
#        grad_fn=<AddBackward0>)

# %%
from transformers.models.gpt2.modeling_gpt2 import GPT2Block
desired_layer: GPT2Block = pret.transformer.h[0]
print(input.shape)
desired_layer.forward(input)
# Out:
# torch.Size([1, 1024, 768])
# (tensor([[[ 0.3191,  0.6466,  1.1327,  ..., -0.0743,  0.7379, -0.3372],
#           [-0.3657, -0.3845, -0.2498,  ..., -0.0071,  0.2876,  0.2585],
#           [-1.4182,  0.1991, -0.4063,  ...,  0.0237,  0.1473, -0.4916],
#           ...,
#           [-0.0923,  0.2690, -0.1589,  ..., -1.0229, -0.9910, -0.2968],
#           [-0.0926,  0.3155, -0.1734,  ..., -0.9878, -0.9938, -0.2910],
#           [-0.0140, -0.0124, -0.1848,  ..., -0.5759, -0.4561, -0.2137]]],
#         grad_fn=<AddBackward0>),
#  None)

# %%
import torch
import torch.nn as nn
encoder_layer: nn.TransformerEncoderLayer = custom_model.transformer.transformer.layers[0]
mask = torch.zeros_like(input[:,:,0]).bool()
mask[0,-1] = True
mask[0,-2] = True
mask[0,-3] = True

# import torch.nn as nn
# encoder_layer: nn.TransformerEncoderLayer = custom_model.transformer.transformer.layers[0]
# mask = torch.zeros_like(input[:,:,0]).bool()
# mask[0,-1] = True
# mask[0,-2] = True
# mask[0,-3] = True

# after:  tensor([[[ 0.0275,  0.0141, -0.0031,  ...,  0.5349,  0.2867,  0.1896],
#          [ 0.0340,  0.1176,  0.0336,  ...,  1.1702,  0.1436,  0.4704],
#          [ 0.0355,  0.1407,  0.0450,  ...,  1.1279,  0.0273,  0.4527],
#          ...,
#          [-0.0236,  0.0494,  0.1736,  ..., -0.4440, -1.1006, -0.5862],
#          [-0.0308,  0.0440,  0.1965,  ..., -0.6584, -1.1000, -0.5023],
#          [ 0.0411,  0.1527, -0.0938,  ...,  0.5289,  0.0380,  0.5038]]]

encoder_layer.forward(input, src_mask=mask, is_causal=True)
# Out:
# before:  tensor([[[-0.0665, -0.0487,  0.2646,  ...,  0.2566, -0.1802,  0.0786],
#          [-0.0087, -0.0530, -0.0870,  ..., -0.0863, -0.0397,  0.0746],
#          [-0.0464, -0.0791,  0.1016,  ...,  0.0623,  0.0928, -0.0598],
#          ...,
#          [-0.0018,  0.0016, -0.0551,  ...,  0.0136, -0.0072,  0.0038],
#          [ 0.0032,  0.0016, -0.0489,  ...,  0.0207, -0.0118, -0.0006],
#          [ 0.0003,  0.0030, -0.0017,  ..., -0.0047, -0.0024, -0.0058]]])
# here!
# after:  tensor([[[ 0.0416,  0.0467,  0.1206,  ...,  0.3639, -0.0996, -0.0363],
#          [ 0.0356,  0.0785,  0.1018,  ...,  0.8601,  0.0294,  0.2885],
#          [ 0.0628,  0.1810,  0.1949,  ...,  1.0987, -0.8252,  0.0203],
#          ...,
#          [-0.0205,  0.0474,  0.1777,  ..., -0.4271, -1.1346, -0.6030],
#          [-0.0198,  0.0479,  0.1740,  ..., -0.4534, -1.1293, -0.5940],
#          [ 0.0410,  0.1495, -0.0950,  ...,  0.5224,  0.0520,  0.5131]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[ 0.0416,  0.0467,  0.1206,  ...,  0.3639, -0.0996, -0.0363],
#          [ 0.0356,  0.0785,  0.1018,  ...,  0.8601,  0.0294,  0.2885],
#          [ 0.0628,  0.1810,  0.1949,  ...,  1.0987, -0.8252,  0.0203],
#          ...,
#          [-0.0205,  0.0474,  0.1777,  ..., -0.4271, -1.1346, -0.6030],
#          [-0.0198,  0.0479,  0.1740,  ..., -0.4534, -1.1293, -0.5940],
#          [ 0.0410,  0.1495, -0.0950,  ...,  0.5224,  0.0520,  0.5131]]],
#        grad_fn=<WhereBackward0>)

# %%
input = torch.load("test.pt")
print(input)
# Out:
# tensor([[[-0.0665, -0.0487,  0.2646,  ...,  0.2566, -0.1802,  0.0786],
#          [-0.0087, -0.0530, -0.0870,  ..., -0.0863, -0.0397,  0.0746],
#          [-0.0464, -0.0791,  0.1016,  ...,  0.0623,  0.0928, -0.0598],
#          ...,
#          [-0.0018,  0.0016, -0.0551,  ...,  0.0136, -0.0072,  0.0038],
#          [ 0.0032,  0.0016, -0.0489,  ...,  0.0207, -0.0118, -0.0006],
#          [ 0.0003,  0.0030, -0.0017,  ..., -0.0047, -0.0024, -0.0058]]],
#        requires_grad=True)
# C:\Users\bicke\AppData\Local\Temp\ipykernel_38300\3038415613.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   input = torch.load("test.pt")

# %%
print("hi")
print("hi")
print("hi")
print("hi")
print("hi")
# Out:
# hi
# hi
# hi
# hi
# hi

# %%
import torch
import torch.nn.functional as F

def compare_transformer_layer_side_by_side(input_tensor, layer_idx, cdict, pdict, padding_mask=None, causal_mask=None):
    """
    Compare transformer layer computations (QKV, attention, feedforward) side-by-side with masking and normalization.

    Args:
        input_tensor: Tensor of shape [batch_size, seq_len, d_model].
        layer_idx: Index of the transformer layer to compare.
        cdict: Dictionary with weights from the first model.
        pdict: Dictionary with weights from the second model.
        padding_mask: Tensor of shape [batch_size, 1, seq_len] indicating padded tokens (0 = pad, 1 = valid).
        causal_mask: Tensor of shape [seq_len, seq_len] with -inf on invalid future positions for causal masking.

    Returns:
        None. Prints side-by-side comparisons.
    """

    def get_weight(d, name):
        """Retrieve weights from the appropriate dictionary."""
        return d[name]

    # Step 1: Layer Norm 1 (before self-attention)
    c_ln1_weight = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.norm1.weight")
    c_ln1_bias = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.norm1.bias")

    p_ln1_weight = get_weight(pdict, f"transformer.h.{layer_idx}.ln_1.weight")
    p_ln1_bias = get_weight(pdict, f"transformer.h.{layer_idx}.ln_1.bias")

    c_normed_input = F.layer_norm(input_tensor, input_tensor.shape[-1:], c_ln1_weight, c_ln1_bias)
    p_normed_input = F.layer_norm(input_tensor, input_tensor.shape[-1:], p_ln1_weight, p_ln1_bias)

    # Step 2: In-Projection for QKV
    c_in_proj_weight = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.self_attn.in_proj_weight")
    c_in_proj_bias = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.self_attn.in_proj_bias")

    p_in_proj_weight = get_weight(pdict, f"transformer.h.{layer_idx}.attn.c_attn.weight").T
    p_in_proj_bias = get_weight(pdict, f"transformer.h.{layer_idx}.attn.c_attn.bias")

    c_qkv = F.linear(c_normed_input, c_in_proj_weight, c_in_proj_bias)
    p_qkv = F.linear(p_normed_input, p_in_proj_weight, p_in_proj_bias)

    c_q, c_k, c_v = c_qkv.chunk(3, dim=-1)
    p_q, p_k, p_v = p_qkv.chunk(3, dim=-1)

    # Step 3: Apply Attention Masks
    d_k = c_k.size(-1)

    # Compute raw attention scores
    c_attn_scores = torch.matmul(c_q, c_k.transpose(-2, -1)) / d_k**0.5
    p_attn_scores = torch.matmul(p_q, p_k.transpose(-2, -1)) / d_k**0.5

    # Apply padding mask: Broadcast and use -inf for masked positions
    if padding_mask is not None:
        padding_mask = padding_mask.unsqueeze(1)  # [batch_size, 1, seq_len]
        c_attn_scores = c_attn_scores.masked_fill(padding_mask == 0, float('-inf'))
        p_attn_scores = p_attn_scores.masked_fill(padding_mask == 0, float('-inf'))

    # Apply causal mask (only if provided)
    if causal_mask is not None:
        c_attn_scores = c_attn_scores + causal_mask
        p_attn_scores = p_attn_scores + causal_mask

    # Softmax over the last dimension
    c_attn_weights = F.softmax(c_attn_scores, dim=-1)
    p_attn_weights = F.softmax(p_attn_scores, dim=-1)

    # Step 4: Attention Output
    c_attn_output = torch.matmul(c_attn_weights, c_v)
    p_attn_output = torch.matmul(p_attn_weights, p_v)

    # Step 5: Out-Projection
    c_out_proj_weight = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.self_attn.out_proj.weight").T
    c_out_proj_bias = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.self_attn.out_proj.bias")

    p_out_proj_weight = get_weight(pdict, f"transformer.h.{layer_idx}.attn.c_proj.weight")
    p_out_proj_bias = get_weight(pdict, f"transformer.h.{layer_idx}.attn.c_proj.bias")

    c_final_attn_output = F.linear(c_attn_output, c_out_proj_weight, c_out_proj_bias)
    p_final_attn_output = F.linear(p_attn_output, p_out_proj_weight, p_out_proj_bias)

    # Step 6: Layer Norm 2 (before feedforward)
    c_ln2_weight = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.norm2.weight")
    c_ln2_bias = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.norm2.bias")

    p_ln2_weight = get_weight(pdict, f"transformer.h.{layer_idx}.ln_2.weight")
    p_ln2_bias = get_weight(pdict, f"transformer.h.{layer_idx}.ln_2.bias")

    c_normed_ffn_input = F.layer_norm(c_final_attn_output, c_final_attn_output.shape[-1:], c_ln2_weight, c_ln2_bias)
    p_normed_ffn_input = F.layer_norm(p_final_attn_output, p_final_attn_output.shape[-1:], p_ln2_weight, p_ln2_bias)

    # Step 7: Feedforward Layers
    c_ffn_weight1 = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.linear1.weight")
    c_ffn_bias1 = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.linear1.bias")

    p_ffn_weight1 = get_weight(pdict, f"transformer.h.{layer_idx}.mlp.c_fc.weight").T
    p_ffn_bias1 = get_weight(pdict, f"transformer.h.{layer_idx}.mlp.c_fc.bias")

    c_ffn_intermediate = F.gelu(F.linear(c_normed_ffn_input, c_ffn_weight1, c_ffn_bias1))
    p_ffn_intermediate = F.gelu(F.linear(p_normed_ffn_input, p_ffn_weight1, p_ffn_bias1))

    c_ffn_weight2 = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.linear2.weight")
    c_ffn_bias2 = get_weight(cdict, f"transformer.transformer.layers.{layer_idx}.linear2.bias")

    p_ffn_weight2 = get_weight(pdict, f"transformer.h.{layer_idx}.mlp.c_proj.weight").T
    p_ffn_bias2 = get_weight(pdict, f"transformer.h.{layer_idx}.mlp.c_proj.bias")

    c_ffn_output = F.linear(c_ffn_intermediate, c_ffn_weight2, c_ffn_bias2)
    p_ffn_output = F.linear(p_ffn_intermediate, p_ffn_weight2, p_ffn_bias2)
    print(c_ffn_output)
    # Step 8: Print Comparisons
    print("=== Comparison Results ===")
    print(f"Layer {layer_idx}: Key Difference (Mean Abs Error): {torch.abs(c_q - p_q).mean().item()}")
    print(f"Layer {layer_idx}: Value Difference (Mean Abs Error): {torch.abs(c_v - p_v).mean().item()}")
    print(f"Layer {layer_idx}: Attention Output Difference (Mean Abs Error): {torch.abs(c_final_attn_output - p_final_attn_output).mean().item()}")
    print(f"Layer {layer_idx}: Feedforward Output Difference (Mean Abs Error): {torch.abs(c_ffn_output - p_ffn_output).mean().item()}")

# Example Usage
# input_tensor = torch.randn(1, 10, 768)  # Example input
padding_mask = torch.ones_like(input[:,:,0])
causal_mask = torch.triu(torch.full((input.size(1), input.size(1)), float('-inf')), diagonal=1)  # Example causal mask

compare_transformer_layer_side_by_side(input, layer_idx=0, cdict=cdict, pdict=pdict, 
                                       padding_mask=padding_mask, causal_mask=causal_mask)
# Out:
# tensor([[[ 22.5750,  -5.0417,   1.8624,  ...,   1.1743,  -0.1306,  18.6665],
#          [ 23.3278,  -6.2623,   0.4830,  ...,   2.9826,   1.1707,  24.2999],
#          [ 25.9114,  -5.0044, -15.8205,  ...,   4.4183,   6.1842,  17.8748],
#          ...,
#          [  3.0046, -10.0213,   8.7635,  ...,   0.5806,   4.0622, -12.4676],
#          [  3.1045,  -9.8152,   8.4605,  ...,   0.7042,   4.1607, -12.4692],
#          [ -0.3725,  -9.3246,   9.0403,  ...,   3.3782,   3.5558, -12.7108]]],
#        grad_fn=<ViewBackward0>)
# === Comparison Results ===
# Layer 0: Key Difference (Mean Abs Error): 0.0
# Layer 0: Value Difference (Mean Abs Error): 0.0
# Layer 0: Attention Output Difference (Mean Abs Error): 0.0
# Layer 0: Feedforward Output Difference (Mean Abs Error): 0.0

# %%
def get_weight(d, name):
        """Retrieve weights from the appropriate dictionary."""
        return d[name]
print(get_weight(cdict, f"transformer.transformer.layers.{0}.self_attn.out_proj.weight"))
print(get_weight(pdict, f"transformer.h.{0}.attn.c_proj.weight"))
# Out:
# tensor([[ 0.3127, -0.2442, -0.4301,  ...,  0.0202,  0.0171, -0.1011],
#         [-0.1874, -0.1978,  0.1544,  ...,  0.1984,  0.0252, -0.0735],
#         [ 0.0980, -0.1098,  0.0538,  ..., -0.1482, -0.0184, -0.0024],
#         ...,
#         [-0.0120, -0.0162,  0.0143,  ...,  0.0235, -0.0008,  0.0063],
#         [ 0.0094,  0.0250, -0.0181,  ...,  0.0107,  0.0086,  0.0132],
#         [-0.0309,  0.0459, -0.0016,  ..., -0.0150,  0.0050, -0.0171]])
# tensor([[ 0.3127, -0.1874,  0.0980,  ..., -0.0120,  0.0094, -0.0309],
#         [-0.2442, -0.1978, -0.1098,  ..., -0.0162,  0.0250,  0.0459],
#         [-0.4301,  0.1544,  0.0538,  ...,  0.0143, -0.0181, -0.0016],
#         ...,
#         [ 0.0202,  0.1984, -0.1482,  ...,  0.0235,  0.0107, -0.0150],
#         [ 0.0171,  0.0252, -0.0184,  ..., -0.0008,  0.0086,  0.0050],
#         [-0.1011, -0.0735, -0.0024,  ...,  0.0063,  0.0132, -0.0171]])

# %%
#already loaded in 
custom_model.load_state_dict(cdict)

pdict2 = pret.state_dict()
cdict2 = custom_model.state_dict()
# print(pdict2["transformer.h.0.attn.c_attn.weight"].shape)
print(cdict2["transformer.transformer.layers.0.self_attn.in_proj_weight"].shape)
# if False:
i = 0 
layer_explicit_map = {
        f"transformer.transformer.layers.{i}.linear1.weight" : f"transformer.h.{i}.mlp.c_fc.weight" ,
        f"transformer.transformer.layers.{i}.linear1.bias" : f"transformer.h.{i}.mlp.c_fc.bias" ,
        f"transformer.transformer.layers.{i}.linear2.weight" : f"transformer.h.{i}.mlp.c_proj.weight", 
        f"transformer.transformer.layers.{i}.linear2.bias" : f"transformer.h.{i}.mlp.c_proj.bias" ,
        f"transformer.transformer.layers.{i}.norm1.weight" : f"transformer.h.{i}.ln_1.weight", 
        f"transformer.transformer.layers.{i}.norm1.bias" : f"transformer.h.{i}.ln_1.bias", 
        f"transformer.transformer.layers.{i}.norm2.weight" : f"transformer.h.{i}.ln_2.weight", 
        f"transformer.transformer.layers.{i}.norm2.bias" : f"transformer.h.{i}.ln_2.bias", 
        f"transformer.transformer.layers.{i}.self_attn.out_proj.weight" : f"transformer.h.{i}.attn.c_proj.weight", 
        f"transformer.transformer.layers.{i}.self_attn.out_proj.bias" : f"transformer.h.{i}.attn.c_proj.bias",
        f"transformer.transformer.layers.{i}.self_attn.in_proj_weight":  f"transformer.h.{i}.attn.c_attn.weight",
        f"transformer.transformer.layers.{i}.self_attn.in_proj_bias" : f"transformer.h.{i}.attn.c_attn.bias"
    }

# for k,v in layer_explicit_map.items():
#     print(k, " : ", v)
#     if (cdict2[k].ndim == 2):
#         print(cdict2[k][0:2, 0:2], "\n",pdict2[v][0:2, 0:2])
#     else:
#         print(cdict2[k][0:2], "\n",pdict2[v][0:2])
#     print("----")

from bpe import BPETokenizer

tokenizer = BPETokenizer()

x = tokenizer("Once upon a time")
y = custom_model.forward_ppo_with_tokens(x, torch.zeros_like(x),0)
# Out:
# torch.Size([2304, 768])
# tensor([[[ 0.0640,  0.0319,  0.2790,  ...,  0.1174, -0.5077, -0.0804],
#          [ 0.0231,  0.0954,  0.1616,  ...,  0.6527,  0.1649,  0.4462],
#          [ 0.0209,  0.1981,  0.2516,  ...,  1.7870, -1.1436, -0.2067],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[-0.0405,  0.0338,  0.1512,  ..., -0.0528, -0.2312, -0.1364],
#          [-0.0473, -0.1592, -0.0459,  ..., -0.0747, -0.0718,  0.0230],
#          [-0.0591,  0.0242,  0.0416,  ..., -0.0872, -0.2288,  0.0392],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[-0.0713,  0.0525,  0.0008,  ...,  0.0723,  0.0698,  0.0760],
#          [-0.1151,  0.0458,  0.0486,  ..., -0.0596,  0.1951, -0.0777],
#          [-0.1296,  0.1363,  0.0004,  ...,  0.1516,  0.2382, -0.0499],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[ 0.1563,  0.0490, -0.0857,  ...,  0.0088,  0.0586,  0.1283],
#          [ 0.1939,  0.1394,  0.0019,  ..., -0.1550,  0.0146,  0.0128],
#          [ 0.2944,  0.0286,  0.1165,  ..., -0.1207, -0.1583, -0.1542],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[ 0.0859, -0.1114,  0.2738,  ..., -0.1010,  0.1166,  0.1360],
#          [-0.0590, -0.0013,  0.1789,  ..., -0.1687, -0.0475,  0.1344],
#          [-0.0445, -0.0024,  0.0866,  ..., -0.0164, -0.0011,  0.0946],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[ 0.2895,  0.1869,  0.2052,  ...,  0.1846, -0.0440,  0.1259],
#          [ 0.1116,  0.1157,  0.3562,  ..., -0.1063, -0.0341,  0.0264],
#          [ 0.2858,  0.0098,  0.1400,  ..., -0.1323, -0.0150,  0.0576],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[ 0.1872, -0.1428, -0.2994,  ...,  0.1226, -0.0903,  0.1426],
#          [ 0.0465, -0.0949,  0.0620,  ...,  0.3448, -0.3762, -0.0034],
#          [-0.1434,  0.1046,  0.0146,  ...,  0.1178, -0.0111,  0.4658],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[ 0.1859,  0.0282,  0.3267,  ..., -0.1431,  0.0985, -0.0023],
#          [ 0.4542, -0.1907,  0.0143,  ..., -0.0258,  0.2203, -0.0018],
#          [ 0.2451,  0.0037,  0.0243,  ..., -0.0190, -0.0218, -0.0808],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[-0.0798, -0.0264, -0.2710,  ..., -0.2042,  0.5130, -0.1395],
#          [-0.0595,  0.1122, -0.5766,  ..., -0.1633,  0.2629,  0.1831],
#          [ 0.0217, -0.1350, -0.4556,  ..., -0.0820,  0.1574, -0.2013],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[-0.1245, -0.3881, -0.0028,  ...,  0.1487, -0.3814,  0.0016],
#          [ 0.0606, -0.1432, -0.0913,  ...,  0.3673, -0.4427, -0.2528],
#          [ 0.0642, -0.4584,  0.0462,  ...,  0.2344, -0.3787, -0.3205],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[-0.2710,  0.1237,  0.5923,  ..., -0.0978,  0.1851, -0.3391],
#          [ 0.0761,  0.1817,  0.4757,  ...,  0.1067,  0.2610, -0.1962],
#          [ 0.2489,  0.2784,  0.2642,  ...,  0.3545,  0.0011, -0.0760],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)
# tensor([[[-0.1007,  0.0383,  0.1032,  ...,  0.0435, -0.0112, -0.0408],
#          [-0.0309, -0.0594,  0.1481,  ..., -0.0086,  0.0184, -0.0272],
#          [-0.1705, -0.0737,  0.1592,  ..., -0.0119,  0.1718, -0.1113],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        grad_fn=<NativeLayerNormBackward0>)

# %%
out = torch.topk(y[0][:,-1,:], k = 5, dim=-1).indices.flatten()

# %%
tokenizer.decode(out)
# Out:
# ' exha loophsenal�士ortium'

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

model = custom_model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def generate(prompt, max_length=50):
    input_ids = tokenizer.encode(prompt, return_tensors='pt').to(device)
    for _ in range(max_length):
        with torch.no_grad():
            outputs = model.forward_ppo_with_tokens(input_ids, torch.zeros_like(input_ids),0)[0][:,-1,:]
            
        next_token_id = outputs.argmax(dim=-1).unsqueeze(-1)
        input_ids = torch.cat([input_ids, next_token_id], dim=-1)
        print(tokenizer.decode(input_ids[0], skip_special_tokens=True))
        if next_token_id.item() == tokenizer.eos_token_id:
            break

generate("Once upon a time, in a land far away,")
# Out:
# tensor([[[ 3.3518e-02, -2.6569e-02,  2.7954e-01,  ...,  4.5128e-01,
#           -1.1943e+00, -3.4916e-01],
#          [ 1.3215e-01,  1.4704e-01, -7.9121e-04,  ...,  1.2922e+00,
#           -4.8855e-01,  4.5249e-01],
#          [ 5.1359e-03,  1.5167e-01,  3.1902e-01,  ...,  3.9099e-01,
#           -1.0086e+00, -5.3846e-01],
#          ...,
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan]]], device='cuda:0')
# tensor([[[ 0.0192, -0.0702, -0.0269,  ..., -0.0646, -0.4809, -0.1334],
#          [-0.0166, -0.1049,  0.3334,  ..., -0.0491, -0.2395, -0.0789],
#          [ 0.0947,  0.0375,  0.0085,  ..., -0.1998, -0.3473, -0.0491],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0793,  0.0079, -0.0171,  ...,  0.0194,  0.1783,  0.0086],
#          [-0.0491,  0.0646,  0.0615,  ..., -0.0029,  0.1921, -0.0264],
#          [-0.0986,  0.1397, -0.1194,  ...,  0.0448,  0.2429,  0.0422],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0143,  0.0747, -0.0039,  ...,  0.1913,  0.2090, -0.0070],
#          [-0.0178,  0.0223,  0.0221,  ..., -0.0027, -0.0847, -0.0013],
#          [ 0.0577,  0.0420,  0.0217,  ...,  0.0678,  0.1129,  0.0487],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0119,  0.0442,  0.0982,  ..., -0.1790, -0.0257,  0.0519],
#          [ 0.1124,  0.0961,  0.1613,  ..., -0.0221,  0.0948,  0.1432],
#          [ 0.0290, -0.0532,  0.1352,  ..., -0.0793, -0.0945,  0.1282],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0726, -0.1870,  0.3789,  ..., -0.1319, -0.2198,  0.3238],
#          [ 0.4499,  0.1375,  0.4633,  ...,  0.1383, -0.5035,  0.2470],
#          [-0.0634, -0.0217,  0.3363,  ...,  0.4143, -0.3151,  0.1764],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0764, -0.0260,  0.0134,  ..., -0.0066, -0.0971,  0.0088],
#          [-0.0320, -0.0080, -0.3649,  ..., -0.0018,  0.1369, -0.0521],
#          [-0.0137,  0.0036,  0.0688,  ...,  0.3487, -0.0985, -0.0104],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.3115,  0.2168, -0.1546,  ..., -0.0456, -0.0986,  0.0406],
#          [-0.0566,  0.1309,  0.1751,  ..., -0.0101,  0.0472,  0.2214],
#          [ 0.0384,  0.1470,  0.2009,  ..., -0.0810, -0.0929,  0.0297],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0507, -0.1011, -0.1012,  ..., -0.0347, -0.2231,  0.3130],
#          [-0.0709, -0.0433, -0.1856,  ...,  0.2058, -0.0271,  0.3925],
#          [-0.1270,  0.1441, -0.1285,  ...,  0.1476, -0.0253, -0.1040],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.2833, -0.2938,  0.0974,  ...,  0.0511,  0.0944, -0.2673],
#          [-0.2023, -0.1546, -0.0376,  ...,  0.0120, -0.1365, -0.1839],
#          [-0.1511, -0.1689,  0.1186,  ..., -0.0289, -0.5098, -0.0252],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.4152,  0.1158,  0.1932,  ..., -0.2886, -0.1904,  0.1558],
#          [ 0.3038,  0.0261, -0.1349,  ..., -0.0140, -0.0935, -0.0216],
#          [ 0.4347,  0.1956, -0.1627,  ...,  0.0740,  0.0845, -0.1344],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0030,  0.0436,  0.0052,  ..., -0.0101,  0.0609,  0.0230],
#          [-0.1031, -0.0043, -0.0771,  ..., -0.0624,  0.0171,  0.0425],
#          [-0.1408, -0.0564,  0.0062,  ..., -0.0049, -0.1804, -0.0115],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph
# tensor([[[ 0.0562,  0.0057,  0.1864,  ...,  0.1720, -0.3544, -0.0598],
#          [ 0.1048, -0.0449,  0.1065,  ...,  1.2278, -0.2023,  0.1314],
#          [ 0.0266,  0.2219,  0.0893,  ...,  0.9505, -0.1076,  0.1818],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0270,  0.0280, -0.0337,  ..., -0.0403, -0.1344, -0.0617],
#          [-0.1058,  0.0308,  0.2241,  ..., -0.1181, -0.0997, -0.1288],
#          [-0.0388,  0.0699, -0.0827,  ..., -0.1094,  0.0619, -0.0835],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0954,  0.0174,  0.0690,  ...,  0.0119,  0.3039,  0.0188],
#          [-0.0082,  0.0907,  0.0197,  ...,  0.1115,  0.0007,  0.0441],
#          [-0.0238,  0.1469,  0.0845,  ...,  0.1268,  0.2762,  0.0071],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.3368,  0.1612, -0.1712,  ..., -0.2585,  0.0633, -0.1323],
#          [ 0.0616,  0.1233,  0.0471,  ..., -0.0927, -0.0117,  0.0938],
#          [ 0.1394,  0.0295, -0.0267,  ...,  0.0718, -0.0069,  0.0141],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0349, -0.0787, -0.0034,  ...,  0.0809, -0.0544, -0.0209],
#          [-0.0003,  0.0042,  0.1943,  ..., -0.0095,  0.1084,  0.2002],
#          [-0.1385,  0.0179,  0.0691,  ...,  0.1811,  0.0278,  0.2736],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1578, -0.0381,  0.1325,  ...,  0.3535,  0.1126,  0.1477],
#          [-0.1346,  0.2091,  0.2293,  ...,  0.0869, -0.0494, -0.0187],
#          [-0.0188, -0.1304, -0.0426,  ..., -0.0336,  0.4705, -0.0173],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0348,  0.1485, -0.3080,  ...,  0.4160, -0.1880,  0.0123],
#          [-0.1596, -0.0400, -0.4005,  ...,  0.3983,  0.4423,  0.2671],
#          [ 0.0114, -0.0061, -0.1183,  ...,  0.4128,  0.0061,  0.2621],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.2792,  0.4094, -0.0640,  ..., -0.1339,  0.2198,  0.1558],
#          [-0.0616,  0.1463,  0.1367,  ...,  0.0443,  0.2819, -0.0495],
#          [-0.1005,  0.2010,  0.1808,  ...,  0.1703, -0.0257,  0.0398],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0955, -0.1430, -0.4781,  ..., -0.0802,  0.3071,  0.1172],
#          [-0.0690,  0.2115,  0.0282,  ..., -0.1222,  0.2485, -0.0251],
#          [ 0.0269, -0.3918, -0.5001,  ...,  0.2182,  0.1670, -0.0069],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0967, -0.5026, -0.2559,  ..., -0.1157, -0.2549, -0.4041],
#          [-0.1223, -0.5517,  0.0272,  ...,  0.2474, -0.4209, -0.0643],
#          [ 0.0885, -0.6732, -0.1803,  ...,  0.0788, -0.3716,  0.0147],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0721,  0.1719,  0.0175,  ..., -0.0224,  0.2234, -0.2085],
#          [ 0.0220,  0.2399,  0.3587,  ...,  0.0310, -0.2551, -0.0427],
#          [-0.0398,  0.4656,  0.2136,  ...,  0.0987, -0.0932, -0.1259],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1004,  0.0121,  0.1608,  ..., -0.0056, -0.0018, -0.0118],
#          [-0.0797,  0.0245,  0.0439,  ...,  0.0793,  0.0030, -0.0468],
#          [-0.0425, -0.0888,  0.0347,  ...,  0.0372,  0.2117, -0.0895],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士
# tensor([[[ 0.0602,  0.0421,  0.1617,  ...,  0.7007, -0.2271, -0.2762],
#          [ 0.0666,  0.0446,  0.0669,  ...,  0.1272, -0.5597,  0.0125],
#          [ 0.0547,  0.1236,  0.0935,  ...,  1.4255, -0.3991, -0.1748],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0261, -0.0134,  0.0683,  ..., -0.0753, -0.2089, -0.0753],
#          [-0.1018, -0.0025,  0.1289,  ..., -0.1988, -0.5300, -0.1023],
#          [ 0.0349, -0.0663,  0.2435,  ..., -0.1814, -0.2865, -0.1461],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0311,  0.0588, -0.0829,  ...,  0.0783,  0.1226,  0.1073],
#          [-0.2624,  0.2329, -0.0678,  ...,  0.1345,  0.1294,  0.0955],
#          [-0.0286,  0.0702,  0.0003,  ...,  0.0587,  0.2225,  0.0722],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0333,  0.2176, -0.0524,  ..., -0.0155,  0.2627,  0.0952],
#          [ 0.2106,  0.3196,  0.0453,  ..., -0.0769,  0.2697,  0.0638],
#          [ 0.0244,  0.3665, -0.0339,  ...,  0.0292,  0.5171,  0.1900],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0387,  0.0396,  0.0598,  ...,  0.0274,  0.1262,  0.2826],
#          [-0.0599,  0.0568,  0.0272,  ...,  0.0845, -0.0087,  0.1686],
#          [-0.1824,  0.0440, -0.0780,  ..., -0.1923,  0.2775,  0.1562],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.2288, -0.1834,  0.1689,  ...,  0.4037, -0.1859, -0.2300],
#          [ 0.0691, -0.3931,  0.1775,  ...,  0.3920, -0.1429, -0.1205],
#          [-0.0708, -0.2739,  0.3584,  ..., -0.0766, -0.3435,  0.0340],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1841, -0.0035,  0.0613,  ...,  0.2148,  0.1628,  0.2827],
#          [ 0.1761,  0.1833, -0.4140,  ...,  0.3306, -0.0155,  0.1928],
#          [-0.0481,  0.2120, -0.3544,  ...,  0.0463,  0.2112,  0.1648],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.3746, -0.0265,  0.0110,  ...,  0.2498, -0.1258, -0.0203],
#          [ 0.0472,  0.0086,  0.0190,  ..., -0.0124, -0.0486, -0.0753],
#          [ 0.0399,  0.0686, -0.0818,  ...,  0.0787, -0.1656, -0.0295],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0211,  0.2087, -0.4398,  ..., -0.1168,  0.2368,  0.0406],
#          [-0.1386, -0.4895, -0.1647,  ..., -0.0085,  0.3412, -0.0021],
#          [-0.1244,  0.0334, -0.4178,  ..., -0.2815,  0.2952,  0.1422],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1582, -0.1633, -0.3365,  ...,  0.1132, -0.4304, -0.0806],
#          [-0.0850, -0.0689,  0.0425,  ...,  0.0910, -0.0146,  0.0175],
#          [ 0.0509, -0.1424, -0.1729,  ..., -0.0362, -0.3538, -0.1974],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1390,  0.3054,  0.1101,  ...,  0.5643, -0.1251, -0.0709],
#          [ 0.2571,  0.1602, -0.0239,  ...,  0.3836, -0.0037, -0.2061],
#          [ 0.2770,  0.0010,  0.0059,  ...,  0.3584, -0.0033, -0.1134],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1608,  0.0290,  0.0887,  ..., -0.0186,  0.1318,  0.2019],
#          [-0.1829, -0.2103, -0.0760,  ..., -0.0314,  0.2055,  0.0250],
#          [-0.0527, -0.0649,  0.0812,  ..., -0.0121,  0.1243, -0.0089],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士�士
# tensor([[[ 7.3552e-02,  3.4110e-02,  7.1030e-03,  ...,  5.7748e-01,
#           -2.6474e-01,  5.3272e-02],
#          [ 9.9826e-02,  1.1779e-01,  1.2884e-01,  ...,  7.9721e-01,
#            1.8462e-03,  1.8579e-01],
#          [ 3.5699e-05,  4.1351e-02,  6.5520e-02,  ...,  7.8924e-01,
#           -4.3024e-01, -2.2055e-01],
#          ...,
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan]]], device='cuda:0')
# tensor([[[ 0.0321,  0.0542,  0.0728,  ..., -0.0334, -0.2034, -0.0313],
#          [-0.0388, -0.0556, -0.0374,  ..., -0.0647, -0.1997, -0.0227],
#          [-0.0034, -0.0301,  0.2298,  ..., -0.0762, -0.2197, -0.1053],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0188,  0.1139,  0.0072,  ...,  0.0091,  0.0230,  0.0495],
#          [-0.0630,  0.0168,  0.0277,  ...,  0.0611,  0.0225,  0.0301],
#          [-0.1033,  0.1286,  0.0010,  ...,  0.0393,  0.1822,  0.0605],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.2096,  0.0963, -0.0510,  ..., -0.1843, -0.0064,  0.0279],
#          [ 0.1753,  0.0628,  0.1198,  ..., -0.2290, -0.0023, -0.0947],
#          [ 0.1326,  0.1489, -0.0540,  ..., -0.0798,  0.1194,  0.0709],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 2.7442e-02,  5.8486e-02,  1.7226e-01,  ..., -5.9859e-02,
#           -1.2847e-05,  1.2489e-01],
#          [ 2.9157e-02, -1.3291e-01,  3.0881e-01,  ...,  1.2925e-01,
#           -1.3659e-01,  2.6253e-01],
#          [ 2.7128e-02, -1.1898e-01, -3.4949e-03,  ...,  7.5077e-02,
#           -1.5587e-03,  1.1884e-01],
#          ...,
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan],
#          [        nan,         nan,         nan,  ...,         nan,
#                   nan,         nan]]], device='cuda:0')
# tensor([[[ 0.1993,  0.1376,  0.3941,  ...,  0.1562,  0.0310,  0.0659],
#          [ 0.1891, -0.0797,  0.4109,  ...,  0.1837, -0.3469, -0.2706],
#          [-0.0055, -0.1185,  0.4735,  ..., -0.1833, -0.0096,  0.0553],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.4203,  0.1053, -0.2550,  ...,  0.0038, -0.1377,  0.2373],
#          [-0.1076,  0.3758,  0.0236,  ...,  0.1145,  0.0885,  0.2769],
#          [-0.0725,  0.1377, -0.3055,  ...,  0.1041,  0.2356,  0.0984],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0395, -0.0526,  0.0874,  ..., -0.1630, -0.0349,  0.0454],
#          [-0.1026,  0.0768,  0.2006,  ..., -0.1306, -0.0373, -0.0065],
#          [-0.1072,  0.0287,  0.0391,  ..., -0.1988,  0.0168,  0.0863],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.2458, -0.0187, -0.0431,  ..., -0.1076, -0.1366, -0.0018],
#          [ 0.0708,  0.0681, -0.2578,  ..., -0.0258, -0.0445, -0.2158],
#          [ 0.0853,  0.1439, -0.1972,  ...,  0.1461, -0.1056, -0.0915],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.2982, -0.0742, -0.0784,  ..., -0.2988,  0.0657, -0.0638],
#          [-0.2294, -0.2286,  0.2093,  ..., -0.0967, -0.1630, -0.1224],
#          [-0.1631, -0.1353,  0.2640,  ...,  0.0012,  0.1123, -0.1441],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0074,  0.3175,  0.0680,  ...,  0.0963,  0.0638,  0.2087],
#          [-0.1095,  0.6123, -0.1199,  ...,  0.0943,  0.0015, -0.0487],
#          [-0.0765,  0.3278,  0.1396,  ..., -0.0124,  0.2083,  0.0616],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0627,  0.0034,  0.0534,  ...,  0.0653, -0.0974,  0.0221],
#          [ 0.0147,  0.0315,  0.0591,  ...,  0.1378,  0.0926,  0.0863],
#          [-0.0314, -0.0573,  0.0921,  ...,  0.1289,  0.0910, -0.0028],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士�士 exha
# tensor([[[ 0.0893,  0.1392,  0.2376,  ...,  0.8016, -0.3089, -0.2132],
#          [ 0.0157, -0.0946,  0.1459,  ...,  0.7490, -0.4611,  0.6246],
#          [ 0.0393,  0.1138,  0.0892,  ...,  1.3902, -0.7659,  0.5406],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0162,  0.0160,  0.3118,  ..., -0.1873, -0.5338, -0.1096],
#          [-0.0078,  0.0092,  0.0445,  ..., -0.0784, -0.1804, -0.0559],
#          [ 0.0048,  0.0076,  0.1168,  ..., -0.1110, -0.1779, -0.0682],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0033,  0.0046, -0.0035,  ...,  0.0069,  0.0696,  0.0491],
#          [-0.0766,  0.1312, -0.0091,  ...,  0.0850,  0.2019,  0.0632],
#          [ 0.0327,  0.0665,  0.0649,  ...,  0.1389,  0.0118,  0.1267],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0249,  0.0410, -0.0789,  ...,  0.3450,  0.5896, -0.0920],
#          [ 0.0298,  0.0409, -0.0712,  ...,  0.0686,  0.0267, -0.1712],
#          [ 0.0540,  0.1024,  0.0435,  ..., -0.0028,  0.0348, -0.0039],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1522, -0.0577,  0.1167,  ..., -0.1554, -0.1337,  0.0894],
#          [ 0.0249, -0.0419,  0.1939,  ..., -0.1110, -0.0165,  0.1701],
#          [ 0.0349,  0.0050, -0.0005,  ..., -0.0757,  0.1617,  0.1318],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1531, -0.3180,  0.4083,  ..., -0.0669, -0.3473, -0.0048],
#          [ 0.0855, -0.1160,  0.3855,  ...,  0.3041,  0.0029,  0.0911],
#          [ 0.5321,  0.1679,  0.6430,  ...,  0.2563, -0.0974, -0.1572],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1720, -0.0813, -0.0625,  ...,  0.3546,  0.0443,  0.2971],
#          [ 0.1041,  0.0352,  0.0249,  ...,  0.1317,  0.0080,  0.2018],
#          [ 0.0133, -0.1043,  0.0447,  ...,  0.1098,  0.0250,  0.3627],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.3074,  0.0149,  0.0235,  ..., -0.1118, -0.0167, -0.0205],
#          [-0.0329,  0.0982, -0.0212,  ...,  0.2747, -0.0199,  0.0401],
#          [-0.1156, -0.0986,  0.0299,  ...,  0.0082,  0.0120, -0.2692],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.2396,  0.1233, -0.4217,  ...,  0.2631, -0.0333, -0.1378],
#          [ 0.1847,  0.1763, -0.2333,  ...,  0.1695, -0.0583, -0.0412],
#          [-0.0895,  0.0032, -0.3055,  ...,  0.0231, -0.1260, -0.1237],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1143,  0.1754, -0.1716,  ..., -0.2677, -0.1386, -0.0615],
#          [-0.0061, -0.0606,  0.0834,  ..., -0.3247, -0.1178,  0.1515],
#          [ 0.0426,  0.2227,  0.0230,  ..., -0.0345, -0.0219,  0.1220],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.2276,  0.0192,  0.0845,  ..., -0.1698,  0.2318,  0.2255],
#          [ 0.2762,  0.3774,  0.4369,  ..., -0.0985,  0.1445,  0.5174],
#          [-0.0211,  0.4099,  0.0578,  ...,  0.0079,  0.0638, -0.0030],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0346, -0.1068,  0.0946,  ..., -0.1658, -0.0193, -0.0179],
#          [-0.0309,  0.0385,  0.0593,  ..., -0.0695,  0.0905,  0.0221],
#          [ 0.0565,  0.0600,  0.0977,  ...,  0.0150, -0.0622,  0.0119],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士�士 exha�士
# tensor([[[ 0.0469,  0.0270,  0.2578,  ...,  0.7999, -0.6159, -0.5377],
#          [ 0.0893,  0.0100,  0.1208,  ..., -0.0402,  0.2642,  0.3198],
#          [ 0.0250,  0.2018,  0.1604,  ...,  1.2640, -0.3332, -0.0281],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0278, -0.0380, -0.0325,  ..., -0.1923, -0.4213, -0.0086],
#          [-0.0773,  0.0356, -0.0481,  ..., -0.1153, -0.2150, -0.0625],
#          [ 0.0070,  0.0271, -0.0383,  ..., -0.0335, -0.0767, -0.0283],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0401,  0.0246,  0.0177,  ...,  0.0693,  0.1729,  0.0879],
#          [-0.1093,  0.0380, -0.0754,  ..., -0.0185,  0.1282,  0.1379],
#          [ 0.0012,  0.0216, -0.0837,  ...,  0.0129,  0.1282,  0.1346],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1600,  0.1454,  0.0720,  ..., -0.0095,  0.1160,  0.0894],
#          [ 0.1083,  0.2637, -0.0596,  ..., -0.0071,  0.1632,  0.0153],
#          [ 0.1030,  0.0408,  0.0850,  ..., -0.0234,  0.0987, -0.1395],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.2897,  0.0541, -0.1037,  ..., -0.3179, -0.3604,  0.3010],
#          [-0.0150, -0.0538,  0.2164,  ..., -0.1971,  0.0213,  0.2097],
#          [ 0.0859,  0.0401,  0.2951,  ..., -0.3594, -0.0754, -0.0725],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0795, -0.1261,  0.1987,  ...,  0.1443, -0.0025,  0.2482],
#          [-0.1955, -0.3175,  0.0807,  ...,  0.1297, -0.3987,  0.2842],
#          [ 0.1117, -0.2026,  0.2143,  ...,  0.2704, -0.1698,  0.0040],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.2156, -0.2322,  0.0307,  ...,  0.2233,  0.2314,  0.4725],
#          [ 0.1308, -0.1712, -0.4538,  ...,  0.2818, -0.0047,  0.3565],
#          [ 0.1132, -0.1706, -0.0957,  ...,  0.1333, -0.0332,  0.1651],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0661, -0.2715, -0.0793,  ...,  0.2655, -0.0612,  0.0281],
#          [-0.0351, -0.1142, -0.0339,  ..., -0.0978,  0.0704, -0.0602],
#          [-0.2947, -0.2506, -0.1211,  ...,  0.1524,  0.1353, -0.0334],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1590,  0.3703, -0.2208,  ..., -0.0265,  0.0541, -0.1372],
#          [-0.0913,  0.0290, -0.0076,  ...,  0.1730, -0.1697, -0.1956],
#          [-0.1100, -0.0999, -0.2326,  ...,  0.4553, -0.2563, -0.1747],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.2881, -0.0202, -0.1077,  ...,  0.0301, -0.3253,  0.2018],
#          [-0.1709, -0.1101, -0.3089,  ...,  0.1042, -0.4134,  0.1784],
#          [-0.0905,  0.0592, -0.0807,  ...,  0.1737, -0.1646,  0.0739],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0205,  0.3015, -0.0065,  ...,  0.0501,  0.2379,  0.2083],
#          [-0.0704,  0.5221, -0.2283,  ...,  0.2621, -0.0587,  0.0095],
#          [ 0.1706,  0.5593, -0.3992,  ...,  0.4884, -0.1459,  0.3041],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0080,  0.1180,  0.0710,  ..., -0.0412,  0.0046, -0.0275],
#          [-0.0582, -0.0420,  0.0724,  ..., -0.0111,  0.1271, -0.0273],
#          [-0.0116,  0.1717, -0.3527,  ..., -0.4648,  0.3784, -0.0245],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士�士 exha�士"
# tensor([[[ 0.0335,  0.0603,  0.1932,  ...,  0.3631, -0.4700, -0.3082],
#          [ 0.0118,  0.0390,  0.2053,  ...,  1.1581, -0.3741, -0.0538],
#          [ 0.0317,  0.2617,  0.2798,  ..., -0.0043, -1.5382, -0.4096],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0016,  0.0008,  0.0958,  ..., -0.0693, -0.2626, -0.1227],
#          [-0.0179,  0.1031,  0.1284,  ..., -0.1113, -0.2466, -0.0391],
#          [ 0.0631,  0.0331,  0.0841,  ..., -0.0979, -0.0350, -0.0062],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1491,  0.0304,  0.0297,  ..., -0.0432,  0.1892,  0.0731],
#          [-0.1550,  0.2056, -0.0486,  ...,  0.0663,  0.0188,  0.0515],
#          [-0.1172,  0.1666, -0.0659,  ..., -0.0283,  0.1883,  0.1060],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1393,  0.0803,  0.0302,  ...,  0.0873,  0.1043,  0.0447],
#          [ 0.0669,  0.1970,  0.0543,  ...,  0.0642,  0.1168,  0.0084],
#          [ 0.1729,  0.0992,  0.1274,  ..., -0.0449,  0.0780,  0.0377],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1159, -0.0465, -0.1444,  ...,  0.0209, -0.0010, -0.0116],
#          [ 0.0736, -0.1180,  0.0077,  ...,  0.0379,  0.0536,  0.0866],
#          [ 0.1129, -0.1259,  0.1881,  ...,  0.0600, -0.0460, -0.0241],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1503,  0.3780, -0.0200,  ...,  0.2589, -0.0025,  0.1261],
#          [ 0.0288,  0.0161,  0.3777,  ..., -0.0030, -0.2634,  0.6716],
#          [ 0.0458, -0.0289,  0.2126,  ...,  0.2666, -0.0048,  0.2325],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1411,  0.0730,  0.1451,  ...,  0.1879,  0.2705,  0.0048],
#          [-0.0134,  0.0372, -0.4637,  ...,  0.3493,  0.2285,  0.1893],
#          [-0.0696,  0.0974, -0.0944,  ...,  0.1378,  0.3813,  0.3134],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1684,  0.2829, -0.0922,  ...,  0.1059, -0.4189, -0.1981],
#          [ 0.2490,  0.2585,  0.1204,  ..., -0.1945, -0.3447, -0.1557],
#          [ 0.2046,  0.0153,  0.2987,  ..., -0.1708, -0.0553, -0.1582],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0687, -0.0276, -0.4321,  ..., -0.1053,  0.2243,  0.0138],
#          [ 0.1068, -0.4960, -0.4476,  ..., -0.1879,  0.4563, -0.0049],
#          [-0.0967,  0.0032,  0.0319,  ...,  0.1667,  0.2254,  0.1654],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0314, -0.0300, -0.4521,  ...,  0.2303, -0.6480, -0.1128],
#          [ 0.1492, -0.1288,  0.2046,  ..., -0.2587, -0.0255,  0.0790],
#          [ 0.0496, -0.3856,  0.1082,  ..., -0.1503, -0.2395, -0.1874],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.2092,  0.0604,  0.2399,  ...,  0.0407,  0.0895, -0.1686],
#          [ 0.1318,  0.1859,  0.0701,  ...,  0.2220,  0.0080, -0.0354],
#          [ 0.2177,  0.0550,  0.4000,  ...,  0.3194,  0.2155, -0.2713],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0710, -0.0946,  0.1455,  ..., -0.0166, -0.0278,  0.0249],
#          [-0.0237, -0.0800,  0.0657,  ..., -0.0038,  0.0736,  0.0280],
#          [-0.1382, -0.0339, -0.0498,  ..., -0.1565,  0.0241, -0.0262],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士�士 exha�士" looph
# tensor([[[ 0.0344,  0.0666,  0.2848,  ...,  0.0077, -1.1491, -0.0556],
#          [ 0.0246,  0.1133,  0.0728,  ...,  0.5904, -0.0122,  0.2382],
#          [ 0.0621, -0.1069,  0.0337,  ...,  0.7693, -0.0479,  0.0939],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0226, -0.0411,  0.1442,  ..., -0.0533, -0.5870, -0.1214],
#          [ 0.1069,  0.0960,  0.1780,  ..., -0.1788, -0.6371,  0.0194],
#          [-0.1460,  0.2330, -0.0524,  ...,  0.1643, -0.2846, -0.0320],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1381, -0.0083,  0.0023,  ...,  0.0081,  0.0979,  0.0819],
#          [-0.1684,  0.1417, -0.0749,  ...,  0.1551,  0.2781,  0.2230],
#          [-0.0594,  0.0900, -0.1121,  ..., -0.0217,  0.1761,  0.1231],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0591,  0.2333,  0.0594,  ...,  0.0421,  0.0478,  0.1546],
#          [-0.0322, -0.0012,  0.1160,  ...,  0.1273,  0.0632,  0.0121],
#          [ 0.0125,  0.2077,  0.1430,  ...,  0.0782,  0.1615,  0.1590],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0030,  0.2395, -0.2414,  ...,  0.1316, -0.1084,  0.1344],
#          [ 0.0706, -0.0180, -0.0705,  ...,  0.0571, -0.2533,  0.2713],
#          [ 0.1418, -0.0571, -0.0645,  ..., -0.2739,  0.0669,  0.0102],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0636,  0.2880,  0.4535,  ..., -0.0060, -0.0635,  0.3450],
#          [-0.1666,  0.0225,  0.0344,  ...,  0.2050, -0.0384,  0.2362],
#          [ 0.0729, -0.1401,  0.5850,  ...,  0.2166, -0.1702, -0.0263],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0214,  0.1521,  0.0715,  ..., -0.0423,  0.2747,  0.1196],
#          [ 0.1070,  0.1053,  0.0014,  ...,  0.2959,  0.1916,  0.2877],
#          [ 0.1921,  0.0813, -0.3243,  ...,  0.2994,  0.2804, -0.0024],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0731,  0.3236, -0.3997,  ..., -0.1414,  0.1292,  0.1445],
#          [-0.0043,  0.0828, -0.2767,  ..., -0.0257,  0.1109, -0.1444],
#          [-0.1492,  0.3927, -0.4269,  ...,  0.0645,  0.1035,  0.1872],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0168,  0.0824, -0.1505,  ...,  0.2364, -0.1991, -0.2447],
#          [ 0.0077,  0.0472, -0.2043,  ..., -0.3642, -0.1526, -0.2101],
#          [ 0.0515,  0.2257,  0.3939,  ..., -0.0266,  0.0506,  0.0751],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.3132, -0.1418,  0.0796,  ..., -0.2064, -0.3000, -0.1035],
#          [-0.0052, -0.1151,  0.1774,  ..., -0.0762, -0.0343, -0.1548],
#          [-0.1564, -0.1570,  0.2459,  ..., -0.1827, -0.2113, -0.0074],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.7696, -0.0129, -0.2546,  ...,  0.0608,  0.3404, -0.0077],
#          [ 0.5576, -0.0525, -0.1768,  ...,  0.0485,  0.2989, -0.3661],
#          [-0.0197, -0.2139,  0.0898,  ...,  0.0405,  0.5004, -0.2242],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0793,  0.0373,  0.0966,  ...,  0.1368,  0.0532, -0.0052],
#          [ 0.0898,  0.0349,  0.0540,  ...,  0.2308,  0.0526,  0.1225],
#          [-0.0071, -0.0046,  0.0222,  ..., -0.0581,  0.0180,  0.0307],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士�士 exha�士" looph�士
# tensor([[[ 0.0475,  0.0254,  0.1504,  ...,  0.0682, -0.3722, -0.3325],
#          [ 0.0340,  0.0640,  0.2262,  ...,  0.8703, -0.7725,  0.2155],
#          [ 0.0395,  0.2206,  0.1809,  ...,  1.9653, -1.2178,  0.2338],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0035, -0.0035,  0.0671,  ..., -0.0510, -0.2347, -0.0030],
#          [ 0.0005, -0.0046,  0.0896,  ..., -0.0616, -0.0722,  0.0041],
#          [-0.0932,  0.0537,  0.2288,  ..., -0.1594, -0.2821,  0.0667],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0402,  0.0917, -0.0035,  ...,  0.0415,  0.1845,  0.0292],
#          [-0.0210,  0.1072, -0.0160,  ...,  0.1348,  0.1723,  0.0207],
#          [ 0.0453,  0.1787,  0.1083,  ..., -0.0099,  0.2524,  0.0640],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1211,  0.1150,  0.0594,  ..., -0.0450,  0.1959,  0.0406],
#          [ 0.0842,  0.0296,  0.0753,  ..., -0.0227,  0.0159,  0.0270],
#          [ 0.0158,  0.2291, -0.0514,  ..., -0.0553,  0.1094,  0.0958],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0522,  0.0647,  0.1309,  ...,  0.1030,  0.0320,  0.2151],
#          [-0.0244, -0.1281,  0.2630,  ...,  0.0452,  0.0251,  0.2261],
#          [ 0.0215, -0.0755,  0.1579,  ..., -0.0959, -0.0461,  0.1140],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
# ...
#          [ 0.1313,  0.0269,  0.0435,  ..., -0.1465, -0.0124,  0.2048],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0186, -0.1547,  0.0443,  ...,  0.1128, -0.2576,  0.0046],
#          [ 0.0048, -0.0854,  0.3985,  ..., -0.0195, -0.1885,  0.0827],
#          [-0.1724, -0.0692,  0.3500,  ..., -0.0291, -0.0886, -0.0025],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1853,  0.0658,  0.0427,  ...,  0.3527, -0.0093, -0.0181],
#          [ 0.0346, -0.0937, -0.1242,  ..., -0.0151, -0.1702, -0.1340],
#          [ 0.0988,  0.3577,  0.0222,  ...,  0.3200, -0.1675, -0.0040],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1295, -0.1347, -0.5985,  ...,  0.2325,  0.2666,  0.1329],
#          [ 0.0468,  0.1198, -0.2187,  ...,  0.2405,  0.2270,  0.1334],
#          [ 0.0020,  0.1073,  0.0017,  ...,  0.1466,  0.0053,  0.3756],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1713,  0.1034,  0.2250,  ...,  0.1311,  0.0125,  0.0199],
#          [ 0.0475, -0.0058,  0.1136,  ..., -0.1675, -0.0229,  0.1102],
#          [ 0.2410,  0.0499,  0.2193,  ..., -0.3173, -0.1938, -0.0158],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0284,  0.0584, -0.4853,  ..., -0.0143,  0.3016,  0.0791],
#          [ 0.0774,  0.0629, -0.1499,  ..., -0.0303,  0.3550, -0.0441],
#          [ 0.0252,  0.1175,  0.0104,  ...,  0.0452,  0.5709, -0.2477],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0068,  0.0507, -0.0020,  ..., -0.1176, -0.5225, -0.1743],
#          [ 0.1010, -0.3656,  0.0399,  ..., -0.1432, -0.0434,  0.0236],
#          [ 0.3519, -0.0702,  0.0120,  ...,  0.2008, -0.6093, -0.1999],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0026, -0.0448, -0.0856,  ...,  0.2822,  0.3781,  0.1352],
#          [ 0.3224, -0.0984, -0.1588,  ..., -0.0346,  0.1483, -0.0600],
#          [ 0.7962, -0.1357,  0.2146,  ...,  0.0992,  0.2133, -0.3048],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0608, -0.0027,  0.1420,  ...,  0.0287,  0.0614,  0.0378],
#          [-0.2266, -0.1888,  0.0474,  ...,  0.0452,  0.0124,  0.0439],
#          [ 0.0136, -0.0758,  0.0669,  ...,  0.0337,  0.0561,  0.0194],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士�士 exha�士" looph�士 exha exha looph looph2 millenn�士 exha exha�士 exha═ exha looph exting looph looph�士 millenn exha�士 exha�士" exha looph�士"�士 exha looph�士ˈ millenn looph Dale Twist�士, exha
# tensor([[[ 0.0339,  0.0137,  0.2373,  ...,  0.4499, -0.0253, -0.3952],
#          [ 0.0575,  0.0324,  0.1996,  ...,  0.9324, -0.9106, -0.2223],
#          [ 0.1415,  0.0940,  0.2402,  ...,  1.2137, -0.9583, -0.1848],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0089,  0.0372,  0.0769,  ..., -0.0742, -0.1799, -0.0433],
#          [-0.0198, -0.0187,  0.1259,  ..., -0.0248, -0.0620, -0.0126],
#          [ 0.0016, -0.0066,  0.0714,  ..., -0.1971, -0.3105,  0.0271],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0734,  0.0620, -0.0232,  ..., -0.0266,  0.1162, -0.0318],
#          [-0.0638,  0.0303,  0.0389,  ..., -0.0042,  0.2164,  0.0136],
#          [-0.1449,  0.0169, -0.0532,  ...,  0.0371,  0.1834,  0.0980],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0149,  0.0336,  0.0221,  ...,  0.0069,  0.3237,  0.0386],
#          [ 0.0904,  0.0320, -0.0752,  ..., -0.0087,  0.2457,  0.0745],
#          [ 0.0789,  0.2258,  0.1117,  ...,  0.1538,  0.0406,  0.0752],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0554,  0.0786, -0.1019,  ...,  0.1834, -0.0687, -0.0868],
#          [ 0.0352, -0.0815, -0.1448,  ..., -0.2117, -0.1613,  0.3455],
#          [ 0.0881, -0.1493,  0.1277,  ..., -0.1741, -0.0376,  0.0102],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.1974, -0.0769,  0.0422,  ...,  0.0654,  0.2669, -0.2451],
#          [-0.0903,  0.0787,  0.0281,  ...,  0.3000,  0.4178,  0.1178],
#          [-0.0038,  0.2275,  0.0124,  ..., -0.0060,  0.3908,  0.0773],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0952,  0.4439,  0.0823,  ..., -0.0423, -0.1046,  0.2760],
#          [ 0.0392,  0.0167, -0.2115,  ...,  0.0127,  0.4130,  0.1994],
#          [ 0.0526,  0.2727, -0.0431,  ..., -0.0126,  0.3713,  0.1814],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0707, -0.0619,  0.1602,  ..., -0.2033, -0.2673,  0.0168],
#          [ 0.0649,  0.0989,  0.0132,  ..., -0.0112,  0.0311,  0.0215],
#          [ 0.0872,  0.0252,  0.2431,  ..., -0.0457, -0.0137,  0.0051],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1642,  0.1257, -0.3506,  ...,  0.1221,  0.2265, -0.0998],
#          [ 0.0245, -0.0046,  0.0269,  ..., -0.1290,  0.2978, -0.0915],
#          [-0.2342, -0.0638, -0.2110,  ..., -0.3467,  0.3461,  0.1924],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0861, -0.4579, -0.0372,  ...,  0.0086, -0.0301, -0.0525],
#          [ 0.1464, -0.5810, -0.1132,  ..., -0.2569, -0.5168, -0.3775],
#          [ 0.0266, -0.0163, -0.1363,  ..., -0.0713, -0.8297, -0.1552],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0621,  0.2672, -0.0350,  ...,  0.1323,  0.2780, -0.1058],
#          [-0.1411,  0.0204, -0.0175,  ..., -0.1200,  0.2596, -0.0981],
#          [ 0.0809,  0.0093, -0.0655,  ...,  0.1935,  0.0868, -0.0087],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1436, -0.0412, -0.0882,  ..., -0.0090, -0.0228, -0.0247],
#          [ 0.0207, -0.1315,  0.0876,  ...,  0.0692,  0.0210,  0.0040],
#          [-0.0483, -0.0053,  0.1886,  ...,  0.0779, -0.0401,  0.0102],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士�士 exha�士" looph�士 exha exha looph looph2 millenn�士 exha exha�士 exha═ exha looph exting looph looph�士 millenn exha�士 exha�士" exha looph�士"�士 exha looph�士ˈ millenn looph Dale Twist�士, exha�士
# tensor([[[ 0.0807,  0.0095,  0.0272,  ...,  0.7925,  0.1627,  0.1841],
#          [ 0.0352,  0.0294,  0.0176,  ...,  1.0259,  0.3104, -0.0230],
#          [ 0.0638,  0.0938,  0.0023,  ...,  1.0792, -0.4206,  0.0077],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0273, -0.1583,  0.1215,  ..., -0.1471, -0.2236,  0.1725],
#          [ 0.0167,  0.0114,  0.0390,  ..., -0.0126, -0.1667,  0.0200],
#          [-0.1341, -0.0962,  0.2093,  ..., -0.1876, -0.1092, -0.0887],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0226, -0.0129, -0.0253,  ...,  0.0344,  0.0144,  0.0755],
#          [-0.0445, -0.0481,  0.0059,  ...,  0.0918,  0.0810,  0.0911],
#          [-0.0029,  0.0328, -0.0054,  ...,  0.1069,  0.0628,  0.1009],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0056,  0.2132,  0.0961,  ...,  0.1039,  0.2575,  0.1368],
#          [ 0.0438,  0.1947, -0.0536,  ...,  0.0515,  0.2403,  0.0225],
#          [ 0.0927,  0.2746,  0.0700,  ...,  0.0833,  0.2274,  0.0881],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0127,  0.0401, -0.4145,  ..., -0.2552, -0.1718,  0.1422],
#          [ 0.0642, -0.1066,  0.1234,  ...,  0.0128, -0.0934,  0.1408],
#          [ 0.0298,  0.0189, -0.0718,  ..., -0.3043,  0.1358,  0.1847],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0663, -0.2031,  0.1455,  ..., -0.4591,  0.1559, -0.2140],
#          [-0.3993, -0.0842,  0.2270,  ..., -0.0989,  0.1630, -0.4278],
#          [-0.0558,  0.0372, -0.0888,  ...,  0.2771,  0.0605, -0.1844],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0402,  0.0967,  0.0510,  ...,  0.3471,  0.1450, -0.0718],
#          [-0.0102, -0.0266,  0.0244,  ...,  0.2788,  0.0704,  0.2742],
#          [ 0.2853,  0.0238,  0.1474,  ...,  0.5161, -0.1887,  0.0328],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.1166, -0.1203, -0.0789,  ...,  0.0303, -0.3948,  0.0894],
#          [-0.2634,  0.0543, -0.0083,  ...,  0.0034, -0.3221, -0.2925],
#          [-0.1215,  0.0454, -0.0441,  ..., -0.2119, -0.0101, -0.1997],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0223,  0.3141,  0.0093,  ...,  0.0830, -0.1983,  0.1069],
#          [ 0.2284, -0.2308, -0.6128,  ..., -0.2063, -0.0517,  0.1558],
#          [ 0.2171,  0.0109, -0.2944,  ...,  0.2717,  0.0365, -0.2788],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0697,  0.0142,  0.0479,  ..., -0.1441,  0.2270, -0.3274],
#          [ 0.0424, -0.0098,  0.0828,  ...,  0.0505, -0.0402,  0.0078],
#          [ 0.0004,  0.1923,  0.1055,  ..., -0.0419, -0.2147,  0.0201],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[ 0.0928,  0.4767, -0.3885,  ...,  0.1823, -0.1491, -0.1236],
#          [ 0.0441,  0.2849,  0.1377,  ...,  0.0303,  0.0189, -0.0142],
#          [ 0.2022,  0.3252,  0.0960,  ...,  0.0643,  0.3003, -0.3744],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# tensor([[[-0.0623, -0.0869,  0.1799,  ..., -0.0956, -0.0295,  0.0326],
#          [-0.0393,  0.0407,  0.0430,  ...,  0.0410,  0.0116,  0.1057],
#          [-0.1475, -0.0387,  0.2067,  ...,  0.2111,  0.0667, -0.0241],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]]],
#        device='cuda:0')
# Once upon a time, in a land far away, looph�士�士 exha�士" looph�士 exha exha looph looph2 millenn�士 exha exha�士 exha═ exha looph exting looph looph�士 millenn exha�士 exha�士" exha looph�士"�士 exha looph�士ˈ millenn looph Dale Twist�士, exha�士�士

# %%
cdict.keys()
# Out:
# odict_keys(['transformer.dual_positional_encoding.learned_positional_encoding.weight', 'transformer.dual_positional_encoding.position_in_thought_encoding.weight', 'transformer.transformer.layers.0.self_attn.in_proj_weight', 'transformer.transformer.layers.0.self_attn.in_proj_bias', 'transformer.transformer.layers.0.self_attn.out_proj.weight', 'transformer.transformer.layers.0.self_attn.out_proj.bias', 'transformer.transformer.layers.0.linear1.weight', 'transformer.transformer.layers.0.linear1.bias', 'transformer.transformer.layers.0.linear2.weight', 'transformer.transformer.layers.0.linear2.bias', 'transformer.transformer.layers.0.norm1.weight', 'transformer.transformer.layers.0.norm1.bias', 'transformer.transformer.layers.0.norm2.weight', 'transformer.transformer.layers.0.norm2.bias', 'transformer.transformer.layers.1.self_attn.in_proj_weight', 'transformer.transformer.layers.1.self_attn.in_proj_bias', 'transformer.transformer.layers.1.self_attn.out_proj.weight', 'transformer.transformer.layers.1.self_attn.out_proj.bias', 'transformer.transformer.layers.1.linear1.weight', 'transformer.transformer.layers.1.linear1.bias', 'transformer.transformer.layers.1.linear2.weight', 'transformer.transformer.layers.1.linear2.bias', 'transformer.transformer.layers.1.norm1.weight', 'transformer.transformer.layers.1.norm1.bias', 'transformer.transformer.layers.1.norm2.weight', 'transformer.transformer.layers.1.norm2.bias', 'transformer.transformer.layers.2.self_attn.in_proj_weight', 'transformer.transformer.layers.2.self_attn.in_proj_bias', 'transformer.transformer.layers.2.self_attn.out_proj.weight', 'transformer.transformer.layers.2.self_attn.out_proj.bias', 'transformer.transformer.layers.2.linear1.weight', 'transformer.transformer.layers.2.linear1.bias', 'transformer.transformer.layers.2.linear2.weight', 'transformer.transformer.layers.2.linear2.bias', 'transformer.transformer.layers.2.norm1.weight', 'transformer.transformer.layers.2.norm1.bias', 'transformer.transformer.layers.2.norm2.weight', 'transformer.transformer.layers.2.norm2.bias', 'transformer.transformer.layers.3.self_attn.in_proj_weight', 'transformer.transformer.layers.3.self_attn.in_proj_bias', 'transformer.transformer.layers.3.self_attn.out_proj.weight', 'transformer.transformer.layers.3.self_attn.out_proj.bias', 'transformer.transformer.layers.3.linear1.weight', 'transformer.transformer.layers.3.linear1.bias', 'transformer.transformer.layers.3.linear2.weight', 'transformer.transformer.layers.3.linear2.bias', 'transformer.transformer.layers.3.norm1.weight', 'transformer.transformer.layers.3.norm1.bias', 'transformer.transformer.layers.3.norm2.weight', 'transformer.transformer.layers.3.norm2.bias', 'transformer.transformer.layers.4.self_attn.in_proj_weight', 'transformer.transformer.layers.4.self_attn.in_proj_bias', 'transformer.transformer.layers.4.self_attn.out_proj.weight', 'transformer.transformer.layers.4.self_attn.out_proj.bias', 'transformer.transformer.layers.4.linear1.weight', 'transformer.transformer.layers.4.linear1.bias', 'transformer.transformer.layers.4.linear2.weight', 'transformer.transformer.layers.4.linear2.bias', 'transformer.transformer.layers.4.norm1.weight', 'transformer.transformer.layers.4.norm1.bias', 'transformer.transformer.layers.4.norm2.weight', 'transformer.transformer.layers.4.norm2.bias', 'transformer.transformer.layers.5.self_attn.in_proj_weight', 'transformer.transformer.layers.5.self_attn.in_proj_bias', 'transformer.transformer.layers.5.self_attn.out_proj.weight', 'transformer.transformer.layers.5.self_attn.out_proj.bias', 'transformer.transformer.layers.5.linear1.weight', 'transformer.transformer.layers.5.linear1.bias', 'transformer.transformer.layers.5.linear2.weight', 'transformer.transformer.layers.5.linear2.bias', 'transformer.transformer.layers.5.norm1.weight', 'transformer.transformer.layers.5.norm1.bias', 'transformer.transformer.layers.5.norm2.weight', 'transformer.transformer.layers.5.norm2.bias', 'transformer.transformer.layers.6 ...

# %%
cdict['transformer.wte.weight']
# Out:
# tensor([[-0.1101, -0.0393,  0.0331,  ..., -0.1364,  0.0151,  0.0453],
#         [ 0.0403, -0.0486,  0.0462,  ...,  0.0861,  0.0025,  0.0432],
#         [-0.1275,  0.0479,  0.1841,  ...,  0.0899, -0.1297, -0.0879],
#         ...,
#         [-0.0445, -0.0548,  0.0123,  ...,  0.1044,  0.0978, -0.0695],
#         [ 0.1860,  0.0167,  0.0461,  ..., -0.0963,  0.0785, -0.0225],
#         [ 0.0514, -0.0277,  0.0499,  ...,  0.0070,  0.1552,  0.1207]])

# %%
# Out:
# 13

# %%
predictions = custom_model.forward_ppo_with_tokens(tokens, torch.zeros_like(tokens),0)[0]
x = predictions.argmax(dim=-1)
t.decode(x[0])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 predictions = custom_model.forward_ppo_with_tokens(tokens, torch.zeros_like(tokens),0)[0]
#       2 x = predictions.argmax(dim=-1)
#       3 t.decode(x[0])
#
# File c:\Users\bicke\Documents\GitHub\Thoughtsformer\one_step_thoughtsformer.py:322, in ThoughtsFormer.forward_ppo_with_tokens(self, tokens, padding_mask, n_thoughts_taken)
#     320   padding_mask = padding_mask.bool()
#     321 # Embed the tokens
# --> 322 state_embeddings = self.token_embedding(tokens)
#     324 # Call the existing forward_ppo method
#     325 return self.forward_ppo(state_embeddings, padding_mask, n_thoughts_taken)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\sparse.py:164, in Embedding.forward(self, input)
#     163 def forward(self, input: Tensor) -> Tensor:
# --> 164     return F.embedding(
#     165         input, self.weight, self.padding_idx, self.max_norm,
#     166         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\functional.py:2267, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2261     # Note [embedding_renorm set_grad_enabled]
#    2262     # XXX: equivalent to
#    2263     # with torch.no_grad():
#    2264     #   torch.embedding_renorm_
#    2265     # remove once script supports set_grad_enabled
#    2266     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2267 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument index in method wrapper_CUDA__index_select)

# %%
tokens.bool().dtype == torch.int64
# Out:
# False

# %%
# Out:
# Number of attention heads: 12

# %%
import torch
from transformers import GPT2Tokenizer

def predict_next_token(model: ThoughtsFormer, tokenizer, sentence, device):
    # Tokenize the input sentence
    input_ids = tokenizer.encode(sentence, return_tensors='pt').to(device)
    
    # Generate attention mask
    attention_mask = torch.zeros_like(input_ids).to(device).bool()
    
    # Get the model's prediction
    with torch.no_grad():
        outputs = model.forward_ppo_with_tokens(input_ids, attention_mask, 0)
        logits = outputs.logits if hasattr(outputs, 'logits') else outputs[0]
    
    # Get the predictions for the last token
    next_token_logits = logits[0, -1, :]
    
    # Get the top 5 candidates
    top_5_tokens = torch.topk(next_token_logits, 5, dim=-1)
    
    return top_5_tokens.indices, top_5_tokens.values

# Set up the model and tokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = ThoughtsFormer(vocab_size=50257, d_embed=768, feed_forward_dim=768 * 4, n_head=12, max_context_length=1024, thought_length=0, sinusoidal_position_encoding=False).to(device)

# Load your trained weights
model = custom_model.to(device)
model.eval()

# Test sentence
test_sentence = "The quick brown fox jumps over the lazy"

# Predict next token
top_indices, top_scores = predict_next_token(model, tokenizer, test_sentence, device)

# Print results
print(f"Input: {test_sentence}")
print("Top 5 predicted next tokens:")
for i, (index, score) in enumerate(zip(top_indices, top_scores), 1):
    token = tokenizer.decode([index])
    print(f"{i}. '{token}' (score: {score.item():.4f})")
# Out:
# c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\transformer.py:720: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   return torch._transformer_encoder_layer_fwd(
# Input: The quick brown fox jumps over the lazy
# Top 5 predicted next tokens:
# 1. ' looph' (score: 14.0095)
# 2. ' exha' (score: 12.0068)
# 3. '�士' (score: 11.4057)
# 4. ' tremend' (score: 9.3803)
# 5. ' millenn' (score: 9.2363)

# %%
# Method 2: Save only the state dictionary (recommended)
torch.save(custom_model.state_dict(), 'gpt2_starting_thoughtsformer.pth')
