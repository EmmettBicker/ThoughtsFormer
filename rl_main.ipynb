# %%
from thoughtsformer_env import ThoughtsFormerEnv
from thoughtsformer_policy import ThoughtsFormerPolicy
from token_level_ppo import TokenLevelPPO
# Out:
# c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\gym\envs\registration.py:307: DeprecationWarning: The package name gym_minigrid has been deprecated in favor of minigrid. Please uninstall gym_minigrid and install minigrid with `pip install minigrid`. Future releases will be maintained under the new package name minigrid.
#   fn()

# %%
n_thoughts = 3
seq_len = 1024 // (n_thoughts+1)

env = ThoughtsFormerEnv(vocab_size=50257, max_sequence_length=seq_len,max_thought_length=n_thoughts)
policy_kwargs = {
    "max_thought_len" : n_thoughts,
    "from_gpt2" : True
}
ppo = TokenLevelPPO(ThoughtsFormerPolicy, env, n_steps=128, batch_size=16, max_sequence_length=seq_len, verbose=2, ent_coef=0.001, policy_kwargs=policy_kwargs)

ppo.learn(1)
# Out:
# c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (301966 > 1024). Running this sequence through the model will result in indexing errors
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\functional.py:5560: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4        |
# |    ep_rew_mean     | -inf     |
# | time/              |          |
# |    fps             | 1        |
# |    iterations      | 1        |
# |    time_elapsed    | 70       |
# |    total_timesteps | 128      |
# ---------------------------------
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 11
#       5 policy_kwargs = {
#       6     "max_thought_len" : n_thoughts,
#       7     "from_gpt2" : True
#       8 }
#       9 ppo = TokenLevelPPO(ThoughtsFormerPolicy, env, n_steps=128, batch_size=16, max_sequence_length=seq_len, verbose=2, ent_coef=0.001, policy_kwargs=policy_kwargs)
# ---> 11 ppo.learn(1)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:313, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     310         assert self.ep_info_buffer is not None
#     311         self._dump_logs(iteration)
# --> 313     self.train()
#     315 callback.on_training_end()
#     317 return self
#
# File c:\Users\bicke\Documents\GitHub\Thoughtsformer\token_level_ppo.py:359, in TokenLevelPPO.train(self)
#     357 rollout_data.observations['state'] = rollout_data.observations['state'].to(torch.long)
#     358 # rollout_data.observations['thought_step']
# --> 359 values, action_log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     361 values = values.view(-1, actions.shape[1]) # (batch x tokens)
#     362 # Normalize advantage
#
# File c:\Users\bicke\Documents\GitHub\Thoughtsformer\thoughtsformer_policy.py:92, in ThoughtsFormerPolicy.evaluate_actions(self, obs, actions)
#      86     idxs = torch.where(thought_steps == value.item())[0]
#      87     temp_obs = {
#      88         'state' : obs['state'][idxs],
#      89         'thought_step' : int(value.item())
#      90     }
# ---> 92     _, values[idxs], _, logits[idxs] = self.forward_with_logits(temp_obs)
#      93 log_probs = F.log_softmax(logits,dim=-1)
#      94 probs = F.softmax(logits, dim=-1)
#
# File c:\Users\bicke\Documents\GitHub\Thoughtsformer\thoughtsformer_policy.py:56, in ThoughtsFormerPolicy.forward_with_logits(self, obs)
#      53 def forward_with_logits(self, obs: dict):
#      54     assert 'state' in obs and 'thought_step' in obs, f"'state' and 'thought_step' should be keys of the observation dictionary"
# ---> 56     logits, values = self.model.forward_ppo_with_tokens(obs['state'], torch.zeros_like(obs['state']), obs['thought_step'])
#      57     sampled_tokens, action_probs = self.sample_tokens(logits)
#      59     return sampled_tokens, values, action_probs, logits
#
# File c:\Users\bicke\Documents\GitHub\Thoughtsformer\thoughtsformer.py:300, in ThoughtsFormer.forward_ppo_with_tokens(self, tokens, padding_mask, n_thoughts_taken)
#     297 state_embeddings = self.token_embedding(tokens)
#     299 # Call the existing forward_ppo method
# --> 300 return self.forward_ppo(state_embeddings, padding_mask, n_thoughts_taken)
#
# File c:\Users\bicke\Documents\GitHub\Thoughtsformer\thoughtsformer.py:269, in ThoughtsFormer.forward_ppo(self, state_embeddings, padding_mask, n_thoughts_taken)
#     265 def forward_ppo(self, state_embeddings: torch.Tensor, padding_mask: torch.Tensor, n_thoughts_taken: int | torch.Tensor) -> tuple[torch.Tensor, torch.Tensor]:
#     266   '''
#     267   Takes in the current state, the padding mask, and the number of thoughts already taken. Outputs the logits for the next action and value for every token in the sequence.
#     268   '''
# --> 269   next_embeddings = self.forward_embeddings(state_embeddings, padding_mask, n_thoughts_taken)
#     270   action_embeddings = self.get_tokens_at_action_location(next_embeddings, n_thoughts_taken)
#     272   return self.policy_feedforward(action_embeddings), self.value_feedforward(action_embeddings).squeeze(dim=2)
#
# File c:\Users\bicke\Documents\GitHub\Thoughtsformer\thoughtsformer.py:260, in ThoughtsFormer.forward_embeddings(self, state_embeddings, padding_mask, n_thoughts_taken)
#     255 padding_mask = self._prepare_thoughtsformer_padding_mask_input(padding_mask)
#     257 # print(torch.sum(padding_mask == 0,dim=1))
#     258 # print( int(torch.sum(padding_mask == 0,dim=1).max()))
# --> 260 next_embeddings = self.transformer(state_embeddings, padding_mask, n_thoughts_taken)
#     261 debug_print("future embeddings\n", next_embeddings,  flag=self.debug)
#     263 return next_embeddings
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\bicke\Documents\GitHub\Thoughtsformer\thoughtsformer.py:133, in ThoughtCausalTransformer.forward(self, x, padding_mask, thoughts_taken)
#     131   plt.imshow(causal_mask)
#     132   plt.show()
# --> 133 x = self.transformer(x, mask=causal_mask, src_key_padding_mask=padding_mask)
#     134 debug_print("embeddings right after transformer forward", x, flag=self.debug)
#     135 return x
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\transformer.py:416, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask, is_causal)
#     413 is_causal = _detect_is_causal_mask(mask, is_causal, seq_len)
#     415 for mod in self.layers:
# --> 416     output = mod(output, src_mask=mask, is_causal=is_causal, src_key_padding_mask=src_key_padding_mask_for_layers)
#     418 if convert_to_nested:
#     419     output = output.to_padded_tensor(0., src.size())
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\bicke\Documents\GitHub\Thoughtsformer\thoughtsformer.py:30, in _NanAwareTransformerEncoderLayer.forward(self, *args, **kwargs)
#      28 def forward(self, *args, **kwargs):
#      29     # print("before: ", args[0])
# ---> 30     output = super().forward(*args, **kwargs)
#      31     # print("after: ", output)
#      32     return torch.where(torch.isnan(output), torch.zeros_like(output), output)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\transformer.py:746, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, is_causal)
#     744 x = src
#     745 if self.norm_first:
# --> 746     x = x + self._sa_block(self.norm1(x), src_mask, src_key_padding_mask, is_causal=is_causal)
#     747     x = x + self._ff_block(self.norm2(x))
#     748 else:
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\transformer.py:757, in TransformerEncoderLayer._sa_block(self, x, attn_mask, key_padding_mask, is_causal)
#     755 def _sa_block(self, x: Tensor,
#     756               attn_mask: Optional[Tensor], key_padding_mask: Optional[Tensor], is_causal: bool = False) -> Tensor:
# --> 757     x = self.self_attn(x, x, x,
#     758                        attn_mask=attn_mask,
#     759                        key_padding_mask=key_padding_mask,
#     760                        need_weights=False, is_causal=is_causal)[0]
#     761     return self.dropout1(x)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\modules\activation.py:1275, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1261     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1262         query, key, value, self.embed_dim, self.num_heads,
#    1263         self.in_proj_weight, self.in_proj_bias,
#    (...)
#    1272         average_attn_weights=average_attn_weights,
#    1273         is_causal=is_causal)
#    1274 else:
# -> 1275     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1276         query, key, value, self.embed_dim, self.num_heads,
#    1277         self.in_proj_weight, self.in_proj_bias,
#    1278         self.bias_k, self.bias_v, self.add_zero_attn,
#    1279         self.dropout, self.out_proj.weight, self.out_proj.bias,
#    1280         training=self.training,
#    1281         key_padding_mask=key_padding_mask,
#    1282         need_weights=need_weights,
#    1283         attn_mask=attn_mask,
#    1284         average_attn_weights=average_attn_weights,
#    1285         is_causal=is_causal)
#    1286 if self.batch_first and is_batched:
#    1287     return attn_output.transpose(1, 0), attn_output_weights
#
# File c:\Users\bicke\anaconda3\envs\megatron\Lib\site-packages\torch\nn\functional.py:5560, in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v, average_attn_weights, is_causal)
#    5557 k = k.view(bsz, num_heads, src_len, head_dim)
#    5558 v = v.view(bsz, num_heads, src_len, head_dim)
# -> 5560 attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
#    5561 attn_output = attn_output.permute(2, 0, 1, 3).contiguous().view(bsz * tgt_len, embed_dim)
#    5563 attn_output = linear(attn_output, out_proj_weight, out_proj_bias)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 288.00 MiB. GPU 0 has a total capacity of 6.00 GiB of which 1.98 GiB is free. Of the allocated memory 2.67 GiB is allocated by PyTorch, and 323.35 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
